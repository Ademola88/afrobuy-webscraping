# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
website = 'https://spiceeupp.co.uk/30-soup-ingredients?id_category=30&n=59'

# %%
response = requests.get(website)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content,'html.parser')

# %%
results = soup.find_all('div', {'class':'right-block'})

# %%
len(results)
# Out:
# 59

# %%
results[0].find('h5', {'class': 'product-name'}).get_text()
# Out:
# '  Tropical Sun... '

# %%
results[0].find('span', {'class': 'price product-price'}).get_text()
# Out:
# ' £ 0.79 '

# %%
name = []
price = []

for result in results:
    
    #name
    try:
        name.append(result.find('h5', {'class': 'product-name'}).get_text())
    except:
        name.append('n/a')
        
     #price
    try:
        price.append(result.find('span', {'class': 'price product-price'}).get_text())
    except:
        price.append('n/a')

# %%
price_overview = pd.DataFrame({'Name': name, 'Price': price })

# %%
price_overview
# Out:
#                        Name     Price
# 0          Tropical Sun...    £ 0.79
# 1     Tropical Sun Fish...    £ 0.59
# 2         Whole Ogbono 70g    £ 2.99
# 3      Spicee Upp Whole...    £ 1.99
# 4     Spicee Upp Smoked...    £ 1.99
# 5             S&T Achi 70g    £ 1.99
# 6       Pride of Africa...    £ 2.99
# 7            S&T Kawun 90g    £ 1.99
# 8           Dried Scent...    £ 1.69
# 9     Dried Ugu Leaves 25g    £ 1.99
# 10          Dried Ukazi...    £ 3.99
# 11     Spicee Upp Whole...    £ 1.99
# 12      Pride of Africa...    £ 1.99
# 13          S&T Herring...    £ 3.29
# 14      Ghana Best Palm...    £ 3.99
# 15      Ghana Best Palm...    £ 2.49
# 16         Tropical Sun...    £ 0.59
# 17            Iru Woro/...    £ 3.33
# 18    Spicee Upp Ground...    £ 1.99
# 19    Dried Periwinkle 50g    £ 3.99
# 20         TS Pumpkin Soup    £ 0.59
# 21            TS Cock Soup    £ 0.69
# 22         POA Uziza Seeds    £ 1.99
# 23               Alom 100g    £ 1.99
# 24          Dried Utazi...    £ 1.29
# 25            Ekwang 1000g    £ 6.19
# 26    PepperSoup Spices...    £ 2.99
# 27     Foy Cameroon Pepper    £ 5.99
# 28       Foy Peppersoup...    £ 5.99
# 29     AF Peanut Butter...    £ 1.99
# 30     AF Smooth Peanut...    £ 1.99
# 31    Saltfish Makayabu...    £ 6.99
# 32    Saltfish Makayabu...    £ 3.99
# 33      Pride of Africa...    £ 3.49
# 34     Dried Panga Catfish    £ 7.99
# 35             Boneless...    £ 3.99
# 36    AF Obe Ata Seasoning    £ 1.99
# 37        Tropical Sun MSG    £ 1.99
# 38     Ugba Oil Beans 130g    £ 3.99
# 39        Fufu (Apku) -...    £ 1.40
# 40      TT Blendz Cubed...    £ 5.99
# 41      TT Blendz Green...    £ 3.99
# 42            TT Blendz...    £ 3.99
# 43    TT Blendz Roughly...    £ 3.99
# 44    TT Blendz Roughly...    £ 3.99
# 45    Frozen Periwinkle...    £ 9.99
# 46        Grace Chicken...    £ 0.65
# 47       Grace Fish Tea...    £ 0.70
# 48        Grace Pumpkin...    £ 0.65
# 49    Ghana Best Garden...    £ 3.99
# 50       Kobi/ Bitoyi -...    £ 2.99
# 51         Ogiri Castor...    £ 2.50
# 52          Ghana Fresh...    £ 3.49
# 53                  Miondo    £ 2.99
# 54    Alligator Pepper/...    £ 0.79
# 55     Ghana Best Shito...    £ 3.49
# 56     Red Skin Peanuts...    £ 6.29
# 57     Spicee Upp Whole...    £ 3.89
# 58    Spicee Upp Ground...    £ 3.89

# %%
price_overview.to_excel('results_spiceeuppsoupingredients_page.xlsx', index=False)
