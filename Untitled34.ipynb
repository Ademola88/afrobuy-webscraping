# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import urllib.parse

# %%
website = 'https://www.royacshop.com/shop/food-items'

# %%
response = requests.get(website)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 9 ]> <html lang="en-US" class="ie9 loading-site no-js"> <![endif]-->
# <!--[if IE 8 ]> <html lang="en-US" class="ie8 loading-site no-js"> <![endif]-->
# <!--[if (gte IE 9)|!(IE)]><!--><html class="loading-site no-js" lang="en-US"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://www.royacshop.com/xmlrpc.php" rel="pingback"/>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <title>African Grocery Online | Your Food Items Online Store - Royac Shop</title>
# <meta content="African, Nigerian and Caribbean food &amp; groceries online in the US. Large option of African food &amp; groceries. Nigerian food items online store in the US" name="description"/>
# <link href="https://www.royacshop.com/shop/food-items" rel="canonical"/>
# ...

# %%
results = soup.find_all('div', {'class':'box-text box-text-products'})

# %%
len(results)
# Out:
# 18

# %%
results[0]
# Out:
# <div class="box-text box-text-products"> <div class="title-wrapper"> <p class="category uppercase is-smaller no-text-overflow product-cat op-7"> Food Items </p> <p class="name product-title woocommerce-loop-product__title"><a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://www.royacshop.com/product/african-black-beans-cowpeas-akidi-igbo">African Black Beans – Cowpeas (Akidi Igbo)</a></p></div><div class="price-wrapper"> <span class="price"><span class="woocommerce-Price-amount amount"><bdi><span class="woocommerce-Price-currencySymbol">$</span>5.00</bdi></span></span></div></div>

# %%
results[0].find('div', {'class': 'title-wrapper'}).get_text().strip('Food Items')
# Out:
# 'African Black Beans – Cowpeas (Akidi Igbo)'

# %%
results[0].find('span', {'class': 'price'}).get_text()
# Out:
# '$5.00'

# %%
name = []
price = []

for result in results:
    
    #name
    try:
        name.append(result.find('div', {'class': 'title-wrapper'}).get_text().strip('Food Items'))
    except:
        name.append('n/a')
        
     #price
    try:
        price.append(result.find('span', {'class': 'price'}).get_text())
    except:
        price.append('n/a')

# %%
price_overview = pd.DataFrame({'Name': name, 'Price': price })

# %%
price_overview
# Out:
#                                              Name   Price
# 0      African Black Beans – Cowpeas (Akidi Igbo)   $5.00
# 1                  Banga Sticks – Banga Soup Spic   $6.00
# 2                       Bouye Baobab Fruit Powder   $6.00
# 3                      Cameroon Njangsa (Njansah)   $4.00
# 4        Classic Onga Stew Seasoning (10 Sachets)   $5.50
# 5            Cocoyam Powder – Ede Uri (Thickener)   $5.00
# 6              Djama Djigui Organic Millet Powder   $7.00
# 7                     Dry Tapioca Flour (Cassava)   $6.00
# 8                 Ehuru (African Calabash Nutmeg)   $7.00
# 9   ine Ground Semolina Flour (Durum Wheat) – 3lb   $6.00
# 10                        ine Potato Starch – 3lb   $5.00
# 11               io-Fio Local Beans (Pigeon Peas)   $7.00
# 12                                     resh Banku   $4.00
# 13               Golden Penny Semovita (Semolina)  $15.00
# 14                              Ground Banga Spic  $10.00
# ...

# %%
name = []
price = []

for i in range(1,9):
    
    #website in a variable
    website = 'https://www.royacshop.com/shop/food-items/page/' + str(i)
    
    #request
    response = requests.get(website)
    
    # soup object
    soup = BeautifulSoup(response.content,'html.parser')
        
    #results
    results = soup.find_all('div', {'class':'box-text box-text-products'})
    
    for result in results:
    
        #name
        try:
            name.append(result.find('div', {'class': 'title-wrapper'}).get_text().strip('Food Items'))
        except:
            name.append('n/a')

         #price
        try:
            price.append(result.find('span', {'class': 'price'}).get_text())
        except:
            price.append('n/a')

# %%
price_overview = pd.DataFrame({'Name': name, 'Price': price })

# %%
price_overview
# Out:
#                                            Name   Price
# 0    African Black Beans – Cowpeas (Akidi Igbo)   $5.00
# 1                Banga Sticks – Banga Soup Spic   $6.00
# 2                     Bouye Baobab Fruit Powder   $6.00
# 3                    Cameroon Njangsa (Njansah)   $4.00
# 4      Classic Onga Stew Seasoning (10 Sachets)   $5.50
# ..                                          ...     ...
# 129                                 Waakye Leav   $6.00
# 130   West African Alligator Pepper – Pack of 5   $8.00
# 131                      Whole Crayfish (Dried)  $12.00
# 132                Whole Nigerian Melon Egusi S  $12.00
# 133                        Whole Nigerian Ogbon  $13.00
#
# [134 rows x 2 columns]

# %%
price_overview.to_excel('results_royalcollection_page.xlsx', index=False)
