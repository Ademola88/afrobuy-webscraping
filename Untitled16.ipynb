# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import urllib.parse

# %%
website = 'https://www.adesfoods.co.uk/ades/fruit-veg-ethnic-foods/frozen-vegetables.html'

# %%
response = requests.get(website)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content,'html.parser')

# %%
results = soup.find_all('div', {'class':'wrapper-hover'})

# %%
len(results)
# Out:
# 15

# %%
results[0]
# Out:
# <div class="wrapper-hover">
# <div class="product-image-container">
# <a class="product-image" href="https://www.adesfoods.co.uk/ades/fruit-veg-ethnic-foods/frozen-vegetables/ades-cassava-dough-2kg.html" itemprop="url" title="Ades Frozen Cassava Dough 2Kg">
# <img alt="Ades Frozen Cassava Dough 2Kg" class="lazy" data-src="https://www.adesfoods.co.uk/media/catalog/product/cache/4/small_image/210x/9df78eab33525d08d6e5fb8d27136e95/i/m/img_5882.jpg" id="product-collection-image-227" src="https://www.adesfoods.co.uk/skin/frontend/base/default/images/mgt_lazy_image_loader/loader.gif" width="210"/>
# </a>
# </div>
# <div class="product-info">
# <h2 class="product-name">
# <a href="https://www.adesfoods.co.uk/ades/fruit-veg-ethnic-foods/frozen-vegetables/ades-cassava-dough-2kg.html" itemprop="name" title="Ades Frozen Cassava Dough 2Kg">
#                                 Ades Frozen Cassava Dough 2Kg
#                             </a>
# </h2>
# <div class="desc_grid" itemprop="description">Cassava Dough Frozen 2Kg                        </div>
# <div class="price-box">
# <span class="regular-price" id="product-price-227">
# <span class="price">£4.49</span> </span>
# </div>
# <div class="actions">
# <form action="https://www.adesfoods.co.uk/ades/checkout/icart/add/uenc/aHR0cHM6Ly93d3cuYWRlc2Zvb2RzLmNvLnVrL2FkZXMvZnJ1aXQtdmVnLWV0aG5pYy1mb29kcy9mcm96ZW4tdmVnZXRhYmxlcy5odG1s/product/227/" id="product_addtocart_form_227" method="post">
# <div id="getdataform227">
# </div>
# <div class="qty-updater"> <a class="left" href="javascript:void(0)" onclick="decrementQty(this);"><i aria-hidden="true" class="fa fa-minus"></i></a>
# <input class="input-text qty" id="227" maxlength="12" name="qty" pattern="\d*" title="Qty" type="text" value="1"/>
# <a class="right" href="javascript:void(0);" onclick="incrementQty(this);"><i aria-hidden="true" class="fa fa-plus"></i></a></div>
# <button class="button btn-cart del-227" onclick="setLocationAjax('https://www.adesfoods.co.uk/ades/checkout/icart/add/uenc/aHR0cHM6Ly93d3cuYWRlc2Zvb2RzLmNvLnVrL2FkZXMvZnJ1aXQtdmVnLWV0aG5pYy1mb29kcy9mcm96ZW4tdmVnZXRhYmxlcy5odG1s/product/227/','227')" title="Add to Cart" type="button"><span><span>Add</span></span></button>
# <span id="ajax_loader227" style="display:none"><img src="https://www.adesfoods.co.uk/skin/frontend/adesfoods/default/images/opc-ajax-loader.gif"/></span>
# <span class="basket-btn" id="inBasket_show_227" style="display:none;"><i aria-hidden="true" class="fa fa-check"></i><span id="inBasketQty227">0</span> in basket</span>
# </form>
# <script type="text/javascript">
#
#
# 										 var productAddToCartForm_227 = new VarienForm('product_addtocart_form_227');
# 										 productAddToCartForm_227.submit = function(){
#
# 										 if (this.validator.validate()) {
# 										var url = jQuery('#product_addtocart_form_227').attr( 'action' );
# 										//alert(url);return false;
# 										 //ajaxcart.ajaxCartSubmit(this);
# 												// this.form.submit();
# 												jQuery.ajax( {
# 												url : url,
# 												async:false,
# 												method:'post',
# 												data: jQuery("#product_addtocart_form_227").serialize(),
# 												success : function(transport) {
# 													var resp=new String(transport);
# 													evaluate(resp);
# 												},
# 												error: function (textStatus, errorThrown) {
# 												}
# 												});
# 												  jQuery('#product_addtocart_227').modal('hide');
# 												  jQuery.post( "https://www.adesfoods.co.uk/ades/checkout/icart/productcnt/", { product: "227" })
# 												.done(function( data ) {
# 													if(data!=0){
# 													jQuery('#inBasketQty227').html(data);
# 													jQuery('#inBasket_show_227').show();
# 													}
# 												});
# 											 }
# 										 }.bind(productAddToCartForm_227);
#
# 									</script>
# <div class="clearfix"></div>
# <ul class="add-to-links">
# <li><a class="link-wishlist" href="https://www.adesfoods.co.uk/ades/wishlist/index/add/product/227/form_key/SLrAWsq5SM8hCgm3/">Add to Wishlist</a></li>
# </ul>
# </div>
# </div>
# <div class="label-product">
# </div>
# </div>

# %%
results[0].find('h2', {'class': 'product-name'}).get_text()
# Out:
# '\n\n                                Ades Frozen Cassava Dough 2Kg\n                            \n'

# %%
results[0].find('div', {'class': 'price-box'}).get_text()
# Out:
# '\n\n£4.49 \n'

# %%
product_name_class = results[0].find('h2', {'class': 'product-name'})
relative_url = product_name_class.find('a').get('href')

# %%
root_url = 'https://www.adesfoods.co.uk/'

# %%
url_combine = root_url + relative_url
print(url_combine)
# Out:
# https://www.adesfoods.co.uk/https://www.adesfoods.co.uk/ades/fruit-veg-ethnic-foods/frozen-vegetables/ades-cassava-dough-2kg.html

# %%
product_name = []
product_price = []
relative_url = []

for i in range(1,5):
    website = 'https://www.adesfoods.co.uk/ades/fruit-veg-ethnic-foods/frozen-vegetables.html?p=' + str(i)
    
    #request
    response = requests.get(website)
    
    # soup object
    soup = BeautifulSoup(response.content,'html.parser')
    
    # results
    results = soup.find_all('div', {'class':'wrapper-hover'})
    
    #loop through results
    for result in results:
         #name
        try:
            product_name.append(result.find('h2', {'class': 'product-name'}).get_text())
        except:
            product_name.append('n/a')

         #price
        try:
            product_price.append(result.find('div', {'class': 'price-box'}).get_text())
        except:
            product_price.append('n/a')

         #relative url
        try:
            relative_url.append(result.find('a').get('href'))
        except:
            relative_url.append('n/a')

# %%
url_combined = []

for link in relative_url:
    url_combined.append(urllib.parse.urljoin(root_url,link))

# %%
product_overview = pd.DataFrame({'Name': product_name, 'Price': product_price })

# %%
product_overview
# Out:
#                                                  Name  \
# 0   \n\n                                Ades Froze...
# 1   \n\n                                Ades Froze...
# 2   \n\n                                Ades Froze...
# 3   \n\n                                Ardo Froze...
# 4   \n\n                                Ardo Froze...
# 5   \n\n                                Ardo Froze...
# 6   \n\n                                Ardo Froze...
# 7   \n\n                                Ardo Froze...
# 8   \n\n                                Ardo Froze...
# 9   \n\n                                Ardo Froze...
# 10  \n\n                                Ardo Froze...
# 11  \n\n                                Freezy Coo...
# 12  \n\n                                Frozen Att...
# 13  \n\n                                Frozen Bit...
# 14  \n\n                                Frozen Bit...
# 15  \n\n                                Frozen Bit...
# 16  \n\n                                Frozen Bit...
# 17  \n\n                                Frozen Bob...
# 18  \n\n                                Frozen Bob...
# 19  \n\n                                Frozen Chi...
# 20  \n\n                                Frozen Ekw...
# 21  \n\n                                Frozen Ewe...
# 22  \n\n                                Frozen Ewe...
# 23  \n\n                                Frozen Gre...
# 24  \n\n                                Frozen Gre...
# 25  \n\n                                Frozen Hot...
# 26  \n\n                                Frozen Mat...
# 27  \n\n                                Frozen Mio...
# 28  \n\n                                Frozen Nga...
# 29  \n\n                                Frozen Nga...
# 30  \n\n                                Frozen Oka...
# 31  \n\n                                Frozen Okr...
# 32  \n\n                                Frozen Okr...
# 33  \n\n                                Frozen Pon...
# 34  \n\n                                Frozen Saf...
# 35  \n\n                                Frozen Saf...
# 36  \n\n                                Frozen Sce...
# 37  \n\n                                Frozen Swe...
# 38  \n\n                                Frozen Swe...
# 39  \n\n                                Frozen Ugu...
# 40  \n\n                                Frozen Ugu...
# 41  \n\n                                Frozen Uta...
# 42  \n\n                                Frozen Uzi...
# 43  \n\n                                Frozen Wat...
# 44  \n\n                                Frozen Wat...
# 45  \n\n                                Frozen Who...
# 46  \n\n                                Taj Crushe...
# 47  \n\n                                Taj Crushe...
# 48  \n\n                                Taj Crushe...
#
#                         Price
# 0                \n\n£4.49 \n
# 1                \n\n£5.99 \n
# 2               \n\n£10.99 \n
# 3                \n\n£1.49 \n
# 4                \n\n£3.49 \n
# 5                \n\n£3.99 \n
# 6                \n\n£0.99 \n
# 7                \n\n£1.49 \n
# 8                \n\n£1.49 \n
# 9                \n\n£3.99 \n
# 10               \n\n£0.99 \n
# 11               \n\n£2.99 \n
# 12               \n\n£2.99 \n
# 13               \n\n£1.49 \n
# 14               \n\n£1.99 \n
# 15               \n\n£1.49 \n
# 16  \n\nAs low as:\n£44.99 \n
# 17               \n\n£3.49 \n
# 18               \n\n£2.49 \n
# 19               \n\n£2.49 \n
# 20               \n\n£3.99 \n
# 21               \n\n£1.49 \n
# 22  \n\nAs low as:\n£24.99 \n
# 23               \n\n£1.49 \n
# 24               \n\n£1.99 \n
# 25               \n\n£2.49 \n
# 26               \n\n£1.00 \n
# 27               \n\n£2.49 \n
# 28               \n\n£1.49 \n
# 29  \n\nAs low as:\n£44.99 \n
# 30               \n\n£1.49 \n
# 31               \n\n£1.49 \n
# 32               \n\n£2.99 \n
# 33               \n\n£1.49 \n
# 34               \n\n£2.49 \n
# 35               \n\n£4.49 \n
# 36               \n\n£2.99 \n
# 37               \n\n£1.49 \n
# 38  \n\nAs low as:\n£44.99 \n
# 39               \n\n£1.49 \n
# 40  \n\nAs low as:\n£44.99 \n
# 41               \n\n£2.99 \n
# 42               \n\n£1.99 \n
# 43               \n\n£1.49 \n
# 44               \n\n£1.99 \n
# 45               \n\n£1.99 \n
# 46               \n\n£1.29 \n
# 47               \n\n£1.29 \n
# 48               \n\n£1.29 \n

# %%
product_overview.to_excel('results_frozenvegetables_page.xlsx', index=False)
