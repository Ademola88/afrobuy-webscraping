# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import urllib.parse

# %%
website = 'https://www.adesfoods.co.uk/ades/fish-meat-poutry/frozen-fish.html'

# %%
response = requests.get(website)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content,'html.parser')

# %%
results = soup.find_all('div', {'class':'wrapper-hover'})

# %%
len(results)
# Out:
# 15

# %%
results[0]
# Out:
# <div class="wrapper-hover">
# <div class="product-image-container">
# <a class="product-image" href="https://www.adesfoods.co.uk/ades/fish-meat-poutry/frozen-fish/catfish-frozen-medium-2-5-kg.html" itemprop="url" title="Frozen Catfish (500-800) 2.5Kg">
# <img alt="Frozen Catfish (500-800) 2.5Kg" class="lazy" data-src="https://www.adesfoods.co.uk/media/catalog/product/cache/4/small_image/210x/9df78eab33525d08d6e5fb8d27136e95/i/m/img_7564_2.jpg" id="product-collection-image-1981" src="https://www.adesfoods.co.uk/skin/frontend/base/default/images/mgt_lazy_image_loader/loader.gif" width="210"/>
# </a>
# </div>
# <div class="product-info">
# <h2 class="product-name">
# <a href="https://www.adesfoods.co.uk/ades/fish-meat-poutry/frozen-fish/catfish-frozen-medium-2-5-kg.html" itemprop="name" title="Frozen Catfish (500-800) 2.5Kg">
#                                 Frozen Catfish (500-800) 2.5Kg
#                             </a>
# </h2>
# <div class="desc_grid" itemprop="description">Frozen Catfish - (500-800) 2.5 Kg                        </div>
# <div class="price-box">
# <span class="regular-price" id="product-price-1981">
# <span class="price">£7.99</span> </span>
# </div>
# <div class="actions">
# <a class="button" href="https://www.adesfoods.co.uk/ades/fish-meat-poutry/frozen-fish/catfish-frozen-medium-2-5-kg.html" title="View Details">View Details</a>
# <div class="clearfix"></div>
# <ul class="add-to-links">
# <li><a class="link-wishlist" href="https://www.adesfoods.co.uk/ades/wishlist/index/add/product/1981/form_key/z6kE6iPRgVnqQDlY/">Add to Wishlist</a></li>
# </ul>
# </div>
# </div>
# <div class="label-product">
# </div>
# </div>

# %%
results[0].find('h2', {'class': 'product-name'}).get_text()
# Out:
# '\n\n                                Frozen Catfish (500-800) 2.5Kg\n                            \n'

# %%
results[0].find('div', {'class': 'price-box'}).get_text()
# Out:
# '\n\n£7.99 \n'

# %%
product_name_class = results[0].find('h2', {'class': 'product-name'})
relative_url = product_name_class.find('a').get('href')

# %%
root_url = 'https://www.adesfoods.co.uk/'

# %%
url_combine = root_url + relative_url
print(url_combine)
# Out:
# https://www.adesfoods.co.uk/https://www.adesfoods.co.uk/ades/fish-meat-poutry/frozen-fish/catfish-frozen-medium-2-5-kg.html

# %%
product_name = []
product_price = []
relative_url = []

for i in range(1,5):
    website = 'https://www.adesfoods.co.uk/ades/fish-meat-poutry/frozen-fish.html?p=' + str(i)
    
    #request
    response = requests.get(website)
    
    # soup object
    soup = BeautifulSoup(response.content,'html.parser')
    
    # results
    results = soup.find_all('div', {'class':'wrapper-hover'})
    
    #loop through results
    for result in results:
         #name
        try:
            product_name.append(result.find('h2', {'class': 'product-name'}).get_text())
        except:
            product_name.append('n/a')

         #price
        try:
            product_price.append(result.find('div', {'class': 'price-box'}).get_text())
        except:
            product_price.append('n/a')

         #relative url
        try:
            relative_url.append(result.find('a').get('href'))
        except:
            relative_url.append('n/a')

# %%
url_combined = []

for link in relative_url:
    url_combined.append(urllib.parse.urljoin(root_url,link))

# %%
product_overview = pd.DataFrame({'Name': product_name, 'Price': product_price })

# %%
product_overview
# Out:
#                                                  Name  \
# 0   \n\n                                Frozen Cat...
# 1   \n\n                                Frozen Cat...
# 2   \n\n                                Frozen Cat...
# 3   \n\n                                Frozen Cat...
# 4   \n\n                                Frozen Cat...
# 5   \n\n                                Frozen Hak...
# 6   \n\n                                Frozen Hak...
# 7   \n\n                                Frozen Hak...
# 8   \n\n                                Frozen Mac...
# 9   \n\n                                Frozen Mac...
# 10  \n\n                                Frozen Mac...
# 11  \n\n                                Frozen Mac...
# 12  \n\n                                Frozen Mac...
# 13  \n\n                                Frozen Mac...
# 14  \n\n                                Frozen Pan...
# 15  \n\n                                Frozen Pan...
# 16  \n\n                                Frozen Pan...
# 17  \n\n                                Frozen Red...
# 18  \n\n                                Frozen Red...
# 19  \n\n                                Frozen Red...
# 20  \n\n                                Frozen Red...
# 21  \n\n                                Frozen Red...
# 22  \n\n                                Frozen Red...
# 23  \n\n                                Frozen Sea...
# 24  \n\n                                Frozen Sea...
# 25  \n\n                                Frozen Sea...
# 26  \n\n                                Frozen Sea...
# 27  \n\n                                Frozen Sea...
# 28  \n\n                                Frozen Til...
# 29  \n\n                                Frozen Til...
# 30  \n\n                                Frozen Til...
# 31  \n\n                                Frozen Til...
# 32  \n\n                                Frozen Til...
# 33  \n\n                                Frozen Til...
# 34  \n\n                                Frozen Til...
# 35  \n\n                                Frozen Til...
# 36  \n\n                                Frozen Who...
# 37  \n\n                                Frozen Who...
# 38  \n\n                                Frozen Yel...
# 39  \n\n                                Frozen Yel...
# 40  \n\n                                Frozen Yel...
# 41  \n\n                                Frozen Yel...
# 42  \n\n                                Frozen Yel...
# 43  \n\n                                Frozen Yel...
# 44  \n\n                                Frozen Yel...
# 45  \n\n                                Jack Macke...
# 46  \n\n                                MACKEREL F...
# 47  \n\n                                Red Snappe...
#
#                         Price
# 0                \n\n£7.99 \n
# 1   \n\nAs low as:\n£15.49 \n
# 2                \n\n£8.99 \n
# 3   \n\nAs low as:\n£16.99 \n
# 4                \n\n£8.99 \n
# 5               \n\n£35.99 \n
# 6                \n\n£7.99 \n
# 7               \n\n£16.99 \n
# 8   \n\nAs low as:\n£20.99 \n
# 9   \n\nAs low as:\n£39.99 \n
# 10  \n\nAs low as:\n£23.99 \n
# 11  \n\nAs low as:\n£44.99 \n
# 12               \n\n£2.99 \n
# 13               \n\n£8.79 \n
# 14               \n\n£2.99 \n
# 15               \n\n£8.99 \n
# 16  \n\nAs low as:\n£15.99 \n
# 17              \n\n£15.99 \n
# 18              \n\n£29.99 \n
# 19              \n\n£29.99 \n
# 20               \n\n£5.99 \n
# 21               \n\n£9.99 \n
# 22  \n\nAs low as:\n£17.99 \n
# 23              \n\n£10.99 \n
# 24               \n\n£9.49 \n
# 25  \n\nAs low as:\n£39.99 \n
# 26              \n\n£17.99 \n
# 27               \n\n£4.99 \n
# 28              \n\n£12.49 \n
# 29  \n\nAs low as:\n£19.99 \n
# 30               \n\n£6.99 \n
# 31  \n\nAs low as:\n£12.99 \n
# 32               \n\n£7.99 \n
# 33  \n\nAs low as:\n£14.49 \n
# 34               \n\n£3.99 \n
# 35  \n\nAs low as:\n£17.49 \n
# 36               \n\n£3.49 \n
# 37               \n\n£3.49 \n
# 38              \n\n£11.99 \n
# 39  \n\nAs low as:\n£22.99 \n
# 40              \n\n£12.99 \n
# 41  \n\nAs low as:\n£23.99 \n
# 42               \n\n£5.99 \n
# 43               \n\n£9.49 \n
# 44              \n\n£15.49 \n
# 45               \n\n£8.79 \n
# 46               \n\n£6.99 \n
# 47              \n\n£11.99 \n

# %%
product_overview.to_excel('results_frozenfish_page.xlsx', index=False)
