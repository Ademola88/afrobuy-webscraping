# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
website = 'https://spiceeupp.co.uk/35-household-cleaning-electricals?id_category=35&n=57'

# %%
response = requests.get(website)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content,'html.parser')

# %%
results = soup.find_all('div', {'class':'right-block'})

# %%
len(results)
# Out:
# 57

# %%
results[0].find('h5', {'class': 'product-name'}).get_text()
# Out:
# '  Charge-it Car... '

# %%
results[0].find('span', {'class': 'price product-price'}).get_text()
# Out:
# ' £ 4.99 '

# %%
name = []
price = []

for result in results:
    
    #name
    try:
        name.append(result.find('h5', {'class': 'product-name'}).get_text())
    except:
        name.append('n/a')
        
     #price
    try:
        price.append(result.find('span', {'class': 'price product-price'}).get_text())
    except:
        price.append('n/a')

# %%
price_overview = pd.DataFrame({'Name': name, 'Price': price })

# %%
price_overview
# Out:
#                        Name     Price
# 0         Charge-it Car...    £ 4.99
# 1                  Lighter    £ 0.50
# 2       Pack of 3 Lighters    £ 1.20
# 3        London Big Ben...    £ 0.70
# 4       5 Yellow Duster...    £ 0.99
# 5            Supa Bin Bags    £ 2.00
# 6          Air Freshner...    £ 1.00
# 7       Core CA 500 Car...    £ 4.99
# 8        Core Micro USB...    £ 4.99
# 9      Core Plug in USB...    £ 4.99
# 10       Core USB Power...    £ 4.99
# 11      Daz 10 cleaning...    £ 3.49
# 12        Dettol Liquid...    £ 3.79
# 13             EE Sim Card    £ 0.99
# 14     EE Pay As You Go...    £ 1.00
# 15        Giff Gaff Sim...    £ 1.00
# 16           GSD Safety...    £ 0.10
# 17    Lebara Mobile Low...    £ 1.00
# 18      Lyca Mobile Pay...    £ 1.00
# 19     O2 International...    £ 1.00
# 20    Palmolive Hygiene...    £ 1.00
# 21          Raw Classic...    £ 1.00
# 22              Rizla Blue    £ 0.90
# 23              Rizla Grey    £ 1.00
# 24       Snappies Cling...    £ 1.29
# 25              Three 3...    £ 0.99
# 26       Three 3 Mobile...    £ 0.99
# 27              Toothpicks    £ 1.00
# 28     Virgin Media Pay...    £ 1.00
# 29     Snappies Kitchen...    £ 1.29
# 30             Rizla Green    £ 0.40
# 31      Swan 120 Filter...    £ 1.00
# 32      Chewing Stick Pack    £ 1.99
# 33              Colgate...    £ 1.00
# 34           Robb Original    £ 1.89
# 35          Clean it 10...    £ 2.49
# 36    Clean And Sparkle...    £ 1.00
# 37    Nicky Soft Tissue...    £ 2.50
# 38      Nicky Kitchen Roll    £ 1.99
# 39        Pampers Baby Dry    £ 4.99
# 40          Pack of 3 -...    £ 3.59
# 41       Wisdom Regular...    £ 1.09
# 42    Wisdom Extra Hard...    £ 1.09
# 43           Antiseptic...    £ 1.99
# 44      Clean & Sparkle...    £ 1.00
# 45         Tiger Safety...    £ 2.49
# 46               Rizla Red    £ 1.00
# 47          Core Earphones    £ 5.99
# 48    Core iPhone Cable 1m    £ 4.99
# 49    Core Charging Kit...    £ 8.99
# 50        African Broom...    £ 2.49
# 51        Aboniki Balm 25g    £ 1.49
# 52          Pack of 2 -...    £ 3.99
# 53       Novi Care Hand...    £ 4.99
# 54     Fairy Washing Up...    £ 1.29
# 55         Dabur Herbal...    £ 1.59
# 56     Close Up Toothpaste    £ 1.59

# %%
price_overview.to_excel('results_spiceeupphouseholdequip_page.xlsx', index=False)
