# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
website = 'https://spiceeupp.co.uk/14-seasonings-sauces-spices?id_category=14&n=188'

# %%
response = requests.get(website)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE HTML>
# ...

# %%
results = soup.find_all('div', {'class':'right-block'})

# %%
len(results)
# Out:
# 188

# %%
results[0]
# Out:
# <div class="right-block"><div class="ttproducthover"><div class="functional-buttons clearfix"><div class="button-container"> <a class="button ajax_add_to_cart_button btn btn-default" data-id-product="17" data-id-product-attribute="0" data-minimal_quantity="1" href="https://spiceeupp.co.uk/cart?add=1&amp;id_product=17&amp;token=e38b8037638b5008478bbd1550d3fd9d" rel="nofollow" title="Add to cart"> <span>Add to cart</span> <span class="tooltip">Add to cart</span> </a> <a class="button lnk_view btn btn-default" href="https://spiceeupp.co.uk/tropical-sun/17-tropical-sun-caribeean-mild-curry-powder-100g.html" title="View"> <span>More</span> <span class="tooltip">More</span> </a></div><div class="wishlist"> <a class="addToWishlist wishlistProd_17" data-rel="17" href="#" onclick="WishlistCart('wishlist_block_list', 'add', '17', false, 1); return false;" title="Add to wishlist"> Add to Wishlist <span class="tooltip">Add to wishlist</span> </a></div><div class="compare"> <a class="add_to_compa
# ...

# %%
results[0].find('h5', {'class': 'product-name'}).get_text()
# Out:
# '  Tropical Sun... '

# %%
results[0].find('span', {'class': 'price product-price'}).get_text()
# Out:
# ' £ 1.29 '

# %%
name = []
price = []

for result in results:
    
    #name
    try:
        name.append(result.find('h5', {'class': 'product-name'}).get_text())
    except:
        name.append('n/a')
        
     #price
    try:
        price.append(result.find('span', {'class': 'price product-price'}).get_text())
    except:
        price.append('n/a')

# %%
price_overview = pd.DataFrame({'Name': name, 'Price': price })

# %%
price_overview
# Out:
#                         Name     Price
# 0           Tropical Sun...    £ 1.29
# 1       POA Achi Powder 70g    £ 1.99
# 2         Jumbo Crayfish...    £ 5.99
# 3       Dunns River Mild...    £ 4.49
# 4      Dunns River Dried...    £ 4.49
# ..                       ...       ...
# 183         Maggi Chilli...    £ 2.19
# 184     Thai Dragon Dark...    £ 1.39
# 185            Onga Chicken    £ 0.25
# 186          Chief Green...    £ 3.99
# 187    Old Africa Jollof...    £ 1.99
#
# [188 rows x 2 columns]

# %%
price_overview.to_excel('results_spiceeuppseasoning_page.xlsx', index=False)
