# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import urllib.parse

# %%
website = 'https://www.adesfoods.co.uk/ades/fruit-veg-ethnic-foods/ethnic-foods.html'

# %%
response = requests.get(website)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content,'html.parser')

# %%
results = soup.find_all('div', {'class':'wrapper-hover'})

# %%
len(results)
# Out:
# 15

# %%
results[0]
# Out:
# <div class="wrapper-hover">
# <div class="product-image-container">
# <a class="product-image" href="https://www.adesfoods.co.uk/ades/fruit-veg-ethnic-foods/ethnic-foods/chopped-frozen-vegetable-fumbua-okok-200g.html" itemprop="url" title=" Frozen Fumbua Vegetable - Chopped 200g">
# <img alt=" Frozen Fumbua Vegetable - Chopped 200g" class="lazy" data-src="https://www.adesfoods.co.uk/media/catalog/product/cache/4/small_image/210x/9df78eab33525d08d6e5fb8d27136e95/placeholder/default/small_image_1_icon_1.jpg" id="product-collection-image-7830" src="https://www.adesfoods.co.uk/skin/frontend/base/default/images/mgt_lazy_image_loader/loader.gif" width="210"/>
# </a>
# </div>
# <div class="product-info">
# <h2 class="product-name">
# <a href="https://www.adesfoods.co.uk/ades/fruit-veg-ethnic-foods/ethnic-foods/chopped-frozen-vegetable-fumbua-okok-200g.html" itemprop="name" title=" Frozen Fumbua Vegetable - Chopped 200g">
#                                  Frozen Fumbua Vegetable - Chopped 200g
#                             </a>
# </h2>
# <div class="desc_grid" itemprop="description"> Frozen Fumbua Vegetable - Chopped 200g                        </div>
# <div class="price-box">
# <span class="regular-price" id="product-price-7830">
# <span class="price">£1.99</span> </span>
# </div>
# <div class="actions">
# <p class="availability out-of-stock"><span>Out of stock</span></p>
# <div class="clearfix"></div>
# <ul class="add-to-links">
# <li><a class="link-wishlist" href="https://www.adesfoods.co.uk/ades/wishlist/index/add/product/7830/form_key/Ei6MGPOoVPUxBbYo/">Add to Wishlist</a></li>
# </ul>
# </div>
# </div>
# <div class="label-product">
# </div>
# </div>

# %%
results[0].find('h2', {'class': 'product-name'}).get_text()
# Out:
# '\n\n                                 Frozen Fumbua Vegetable - Chopped 200g\n                            \n'

# %%
results[0].find('div', {'class': 'price-box'}).get_text()
# Out:
# '\n\n£1.99 \n'

# %%
product_name_class = results[0].find('h2', {'class': 'product-name'})
relative_url = product_name_class.find('a').get('href')

# %%
root_url = 'https://www.adesfoods.co.uk/'

# %%
url_combine = root_url + relative_url
print(url_combine)
# Out:
# https://www.adesfoods.co.uk/https://www.adesfoods.co.uk/ades/fruit-veg-ethnic-foods/ethnic-foods/chopped-frozen-vegetable-fumbua-okok-200g.html

# %%
product_name = []
product_price = []
relative_url = []

for i in range(1,5):
    website = 'https://www.adesfoods.co.uk/ades/fruit-veg-ethnic-foods/ethnic-foods.html?p=' + str(i)
    
    #request
    response = requests.get(website)
    
    # soup object
    soup = BeautifulSoup(response.content,'html.parser')
    
    # results
    results = soup.find_all('div', {'class':'wrapper-hover'})
    
    #loop through results
    for result in results:
         #name
        try:
            product_name.append(result.find('h2', {'class': 'product-name'}).get_text())
        except:
            product_name.append('n/a')

         #price
        try:
            product_price.append(result.find('div', {'class': 'price-box'}).get_text())
        except:
            product_price.append('n/a')

         #relative url
        try:
            relative_url.append(result.find('a').get('href'))
        except:
            relative_url.append('n/a')

# %%
url_combined = []

for link in relative_url:
    url_combined.append(urllib.parse.urljoin(root_url,link))

# %%
product_overview = pd.DataFrame({'Name': product_name, 'Price': product_price })

# %%
product_overview
# Out:
#                                                  Name  \
# 0   \n\n                                 Frozen Fu...
# 1   \n\n                                Achi Ades ...
# 2   \n\n                                Ades Abach...
# 3   \n\n                                Ades Cocoy...
# 4   \n\n                                Ades Froze...
# 5   \n\n                                Ades Froze...
# 6   \n\n                                Ades Froze...
# 7   \n\n                                Ades Froze...
# 8   \n\n                                Ades Froze...
# 9   \n\n                                Ades Froze...
# 10  \n\n                                Ades Froze...
# 11  \n\n                                Ades Froze...
# 12  \n\n                                Ades Froze...
# 13  \n\n                                Ades Froze...
# 14  \n\n                                Ades Groun...
# 15  \n\n                                Ades Ofor ...
# 16  \n\n                                AKARA PAST...
# 17  \n\n                                Aligator P...
# 18  \n\n                                Coconut\n ...
# 19  \n\n                                Dried Bitt...
# 20  \n\n                                Dried Peri...
# 21  \n\n                                Fresh Gree...
# 22  \n\n                                Fresh Gree...
# 23  \n\n                                Fresh Puna...
# 24  \n\n                                Fresh Puna...
# 25  \n\n                                Fresh Ripe...
# 26  \n\n                                Fresh Ripe...
# 27  \n\n                                Fresh Ripe...
# 28  \n\n                                Fresh Span...
# 29  \n\n                                Fresh Suga...
# 30  \n\n                                Fresh Whit...
# 31  \n\n                                Fresh Whit...
# 32  \n\n                                Frozen Att...
# 33  \n\n                                Frozen Iru...
# 34  \n\n                                Frozen Mio...
# 35  \n\n                                Frozen Moi...
# 36  \n\n                                Frozen Ogi...
# 37  \n\n                                Frozen Okr...
# 38  \n\n                                Frozen Okr...
# 39  \n\n                                Frozen Saf...
# 40  \n\n                                Frozen Saf...
# 41  \n\n                                Frozen Sta...
# 42  \n\n                                Frozen Wat...
# 43  \n\n                                Frozen Who...
# 44  \n\n                                Kawun Natu...
# 45  \n\n                                Nkwobi Pep...
# 46  \n\n                                Ologi Mill...
# 47  \n\n                                Ologi Yell...
# 48  \n\n                                Ologi Yell...
# 49  \n\n                                PERIWINKLE...
# 50  \n\n                                Taj Tropic...
# 51  \n\n                                UKWA FROZE...
#
#                         Price
# 0                \n\n£1.99 \n
# 1                \n\n£1.99 \n
# 2                \n\n£1.99 \n
# 3                \n\n£1.99 \n
# 4                \n\n£4.49 \n
# 5                \n\n£3.99 \n
# 6                \n\n£1.49 \n
# 7   \n\nAs low as:\n£26.99 \n
# 8                \n\n£1.49 \n
# 9   \n\nAs low as:\n£26.99 \n
# 10  \n\nAs low as:\n£26.99 \n
# 11               \n\n£1.49 \n
# 12               \n\n£5.99 \n
# 13              \n\n£10.99 \n
# 14               \n\n£1.99 \n
# 15               \n\n£1.99 \n
# 16               \n\n£3.49 \n
# 17               \n\n£0.40 \n
# 18               \n\n£1.19 \n
# 19   \n\nAs low as:\n£6.50 \n
# 20               \n\n£2.99 \n
# 21               \n\n£0.50 \n
# 22   \n\nAs low as:\n£1.00 \n
# 23               \n\n£4.00 \n
# 24  \n\nAs low as:\n£37.99 \n
# 25               \n\n£0.50 \n
# 26   \n\nAs low as:\n£1.00 \n
# 27  \n\nAs low as:\n£26.00 \n
# 28               \n\n£0.50 \n
# 29               \n\n£1.99 \n
# 30               \n\n£3.00 \n
# 31  \n\nAs low as:\n£24.99 \n
# 32               \n\n£2.99 \n
# 33               \n\n£5.99 \n
# 34               \n\n£2.49 \n
# 35               \n\n£3.99 \n
# 36               \n\n£1.00 \n
# 37               \n\n£1.49 \n
# 38               \n\n£2.49 \n
# 39               \n\n£2.49 \n
# 40               \n\n£4.49 \n
# 41               \n\n£1.99 \n
# 42               \n\n£1.49 \n
# 43               \n\n£1.99 \n
# 44               \n\n£1.00 \n
# 45               \n\n£1.99 \n
# 46               \n\n£3.99 \n
# 47               \n\n£3.99 \n
# 48               \n\n£3.99 \n
# 49               \n\n£7.99 \n
# 50               \n\n£2.99 \n
# 51               \n\n£2.99 \n

# %%
product_overview.to_excel('results_ethnicfood_page.xlsx', index=False)
