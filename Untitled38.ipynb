# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import urllib.parse

# %%
website = 'https://johnandbiola.co.uk/vegetable'

# %%
response = requests.get(website)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="html-category-page" lang="en">
# <head>
# <title>John and Biola - UK No 1 African Online Supermarket. Vegetable</title>
# <meta content="text/html;charset=utf-8" http-equiv="Content-type"/>
# <meta content="Vegetable" name="description"/>
# <meta content="VEGETABLES everyday essential plantain yam leaf leaves dry exotic Red Hot Pepper Green Ayamase Okra Okro Tomatoes Capscicum Long Onion Garden Eggs Ginger Garlic pona Ghana White wateryam cocoyam sweet potato matoki banana ripe scotch bonnet Coconut Star Apple Agbalumo Asala Awusa Ukpa Ukwe Walnut Bitter Orogbo Gworo Kolanut Obi Abata Oji Kola Alligator Atare Chita mango pawpaw papaya orange grape" name="keywords"/>
# <meta content="nopCommerce" name="generator"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=0, minimum-scale=1.0, maximum-scale=1.0" name="viewport"/>
# <link as="font" crossorigin="" href="/Themes/Pacific/Content/fonts/pacific.woff" rel="preload"/>
# <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@300;400;700&amp;display=swap" rel="stylesheet"/>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-46107175-1"></script>
# <script>
#                   window.dataLayer = window.dataLayer || [];
#                   function gtag(){dataLayer.push(arguments);}
#                   gtag('js', new Date());
#
#                   gtag('config', 'UA-46107175-1');
#
#                 </script>
# <link href="/Themes/Pacific/Content/css/styles.css" rel="stylesheet" type="text/css">
# <link href="/Themes/Pacific/Content/css/footable.css" rel="stylesheet" type="text/css">
# <link href="/Themes/Pacific/Content/css/mobile.css" rel="stylesheet" type="text/css"/>
# <link href="/Themes/Pacific/Content/css/480.css" rel="stylesheet" type="text/css"/>
# <link href="/Themes/Pacific/Content/css/768.css" rel="stylesheet" type="text/css"/>
# <link href="/Themes/Pacific/Content/css/1260.css" rel="stylesheet" type="text/css"/>
# <link href="/Themes/Pacific/Content/css/1500.css" rel="stylesheet" type="text/css"/>
# <link href="/Themes/Pacific/Content/css/1800.css" rel="stylesheet" type="text/css"/>
# <link href="/Plugins/SevenSpikes.Core/Styles/slick-slider-1.6.0.css" rel="stylesheet" type="text/css"/>
# <link href="/Plugins/SevenSpikes.Core/Styles/perfect-scrollbar.min.css" rel="stylesheet" type="text/css"/>
# <link href="/Plugins/SevenSpikes.Nop.Plugins.MegaMenu/Themes/Pacific/Content/MegaMenu.css" rel="stylesheet" type="text/css"/>
# <link href="/Plugins/SevenSpikes.Nop.Plugins.InstantSearch/Themes/Pacific/Content/InstantSearch.css" rel="stylesheet" type="text/css"/>
# <link href="/Plugins/SevenSpikes.Nop.Plugins.AjaxCart/Themes/Pacific/Content/ajaxCart.css" rel="stylesheet" type="text/css"/>
# <link href="/Plugins/SevenSpikes.Nop.Plugins.ProductRibbons/Styles/Ribbons.common.css" rel="stylesheet" type="text/css"/>
# <link href="/Plugins/SevenSpikes.Nop.Plugins.ProductRibbons/Themes/Pacific/Content/Ribbons.css" rel="stylesheet" type="text/css"/>
# <link href="/Plugins/SevenSpikes.Nop.Plugins.QuickView/Themes/Pacific/Content/QuickView.css" rel="stylesheet" type="text/css"/>
# <link href="/lib_npm/fine-uploader/fine-uploader/fine-uploader.min.css" rel="stylesheet" type="text/css"/>
# <link href="https://johnandbiola.co.uk/vegetable" rel="canonical"/>
# <!--Powered by nopCommerce - https://www.nopCommerce.com-->
# </link></link></head>
# <body class="category-page-body">
# <div class="ajax-loading-block-window" style="display: none">
# </div>
# <div id="dialog-notifications-success" style="display:none;" title="Notification">
# </div>
# <div id="dialog-notifications-error" style="display:none;" title="Error">
# </div>
# <div id="dialog-notifications-warning" style="display:none;" title="Warning">
# </div>
# <div class="bar-notification-container" data-close="Close" id="bar-notification">
# </div>
# <!--[if lte IE 8]>
#     <div style="clear:both;height:59px;text-align:center;position:relative;">
#         <a href="http://www.microsoft.com/windows/internet-explorer/default.aspx" target="_blank">
#             <img src="/Themes/Pacific/Content/img/ie_warning.jpg" height="42" width="820" alt="You are using an outdated browser. For a faster, safer browsing experience, upgrade for free today." />
#         </a>
#     </div>
# <![endif]-->
# <div class="master-wrapper-page">
# <div class="header">
# <div class="headeroffer" style="height:35px;background-color:#E1892A; line-height:20px; text-align: left;padding: 8px 5px;">
# <marquee direction="left" onmouseout="this.start()" onmouseover="this.stop()" scrollamount="7">
# <h4 style="color:#fff;">FREE UNLIMITED UK MAINLAND DELIVERY ---------- COLLECT &amp; SAVE ----------  FREE UNLIMITED UK MAINLAND DELIVERY <b style="font-weight:normal;font-size:8px;"><a href="/conditionsofuse">delivery.termsandcondition </a></b></h4>
# </marquee>
# </div>
# <div class="responsive-strip">
# <div class="responsive-logo-wrapper">
# <a class="logo" href="/">
# <img alt="John and Biola Foods" src="/Themes/Pacific/Content/img/logo.png" title=""/>
# </a>
# </div>
# </div>
# <div class="header-upper">
# <div class="header-selectors-wrapper">
# </div>
# <div class="header-links-wrapper">
# <div class="header-links">
# <div class="hedar-links-item">
# <a class="ico-register" href="/register?returnUrl=%2Fvegetable">Register</a>
# </div>
# <div class="hedar-links-item">
# <a class="ico-login" href="/login?returnUrl=%2Fvegetable">Log in</a>
# </div>
# <div class="hedar-links-item">
# <a class="ico-wishlist" href="/wishlist">
# <span class="wishlist-label">Wishlist</span>
# </a>
# </div>
# <div class="hedar-links-item">
# <a class="ico-compare" href="/compareproducts">Compare products list</a>
# </div>
# </div>
# </div>
# </div>
# <div class="header-lower">
# <div class="header-logo">
# <a class="logo" href="/">
# <img alt="John and Biola Foods" src="/Themes/Pacific/Content/img/logo.png" title=""/>
# </a>
# </div>
# <div class="header-menu">
# <div class="menu-button">
# <div class="menu-open" title="Menu">
# <span class="menu-icon-line"></span>
# <span class="menu-icon-line"></span>
# <span class="menu-icon-line"></span>
# </div>
# <div class="menu-close" title="Close"></div>
# </div>
# <div class="menu-header">
# <div class="hedar-links-item">
# <a class="ico-register" href="/register?returnUrl=%2Fvegetable">Register</a>
# </div>
# <div class="hedar-links-item">
# <a class="ico-login" href="/login?returnUrl=%2Fvegetable">Log in</a>
# </div>
# <div class="hedar-links-item">
# <a class="ico-wishlist" href="/wishlist">
# <span class="wishlist-label">Wishlist</span>
# </a>
# </div>
# <div class="hedar-links-item">
# <a class="ico-compare" href="/compareproducts">Compare products list</a>
# </div>
# </div>
# <div class="menu-body">
# <ul class="mega-menu" data-enableclickfordropdown="false" data-isrtlenabled="false">
# <li class="has-sublist with-dropdown-in-grid">
# <a class="with-subcategories" href="/supermarket-shop"><span>Shop</span></a>
# <div class="dropdown categories fullWidth boxes-4">
# <div class="row-wrapper">
# <div class="row"><div class="box">
# <div class="title">
# <a href="/meat" title="Meat"><span>Meat</span></a>
# </div>
# <div class="wrapper">
# <div class="picture">
# <a href="/meat" title="Show products in category Meat">
# <img alt="Picture for category Meat" class="lazy" data-original="https://johnandbiola.co.uk/images/thumbs/0002729_meat_290.jpeg" src="...">
# </img></a>
# </div>
# <ul class="subcategories">
# <li class="subcategory-item">
# <a href="/cow-ox" title="Beef"><span>Beef</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/chicken-hen" title="Chicken, Hen"><span>Chicken, Hen</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/goat" title="Goat, Lamb, Mutton"><span>Goat, Lamb, Mutton</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/turkey-fowl" title="Turkey"><span>Turkey</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/game" title="Exotics"><span>Exotics</span></a>
# </li>
# </ul>
# </div>
# </div><div class="box">
# <div class="title">
# <a href="/fish" title="Seafood"><span>Seafood</span></a>
# </div>
# <div class="wrapper">
# <div class="picture">
# <a href="/fish" title="Show products in category Seafood">
# <img alt="Picture for category Seafood" class="lazy" data-original="https://johnandbiola.co.uk/images/thumbs/0002728_seafood_290.jpeg" src="...">
# </img></a>
# </div>
# <ul class="subcategories">
# <li class="subcategory-item">
# <a href="/frozen-fish" title="Fresh Frozen Fish"><span>Fresh Frozen Fish</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/stockfish" title="Stockfish"><span>Stockfish</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/prawns-crayfish" title="Prawns, Crayfish"><span>Prawns, Crayfish</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/smoked-seafood" title="Smoked, Grilled"><span>Smoked, Grilled</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/delicacy" title="Delicacy"><span>Delicacy</span></a>
# </li>
# </ul>
# </div>
# </div><div class="box">
# <div class="title">
# <a href="/vegetable" title="Vegetables"><span>Vegetables</span></a>
# </div>
# <div class="wrapper">
# <div class="picture">
# <a href="/vegetable" title="Show products in category Vegetables">
# <img alt="Picture for category Vegetables" class="lazy" data-original="https://johnandbiola.co.uk/images/thumbs/0002591_vegetables_290.jpeg" src="..."/>
# </a>
# </div>
# <ul class="subcategories">
# <li class="subcategory-item">
# <a href="/everyday-vegetable" title="Everyday"><span>Everyday</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/plantain" title="Plantain, Yams"><span>Plantain, Yams</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/fresh-leaves" title="Leaves, Seeds"><span>Leaves, Seeds</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/exotic-veg" title="Exotic, Fruit, Herbal"><span>Exotic, Fruit, Herbal</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/frozen-vegetable" title="Frozen"><span>Frozen</span></a>
# </li>
# </ul>
# </div>
# </div><div class="box">
# <div class="title">
# <a href="/spices-cubes" title="Spices, Seasonings "><span>Spices, Seasonings </span></a>
# </div>
# <div class="wrapper">
# <div class="picture">
# <a href="/spices-cubes" title="Show products in category Spices, Seasonings ">
# <img alt="Picture for category Spices, Seasonings " class="lazy" data-original="https://johnandbiola.co.uk/images/thumbs/0001997_spices-seasonings_290.jpeg" src="..."/>
# </a>
# </div>
# <ul class="subcategories">
# <li class="subcategory-item">
# <a href="/jumbo-spices" title="Seasonings"><span>Seasonings</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/exotics" title="Ethnic"><span>Ethnic</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/rajah-spices" title="Rajah"><span>Rajah</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/cubes-sauces" title="Sauces, Paste"><span>Sauces, Paste</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/cubes" title="Chutneys, Pickles"><span>Chutneys, Pickles</span></a>
# </li>
# </ul>
# </div>
# </div></div><div class="row"><div class="box">
# <div class="title">
# <a href="/groceries" title="Groceries"><span>Groceries</span></a>
# </div>
# <div class="wrapper">
# <div class="picture">
# <a href="/groceries" title="Show products in category Groceries">
# <img alt="Picture for category Groceries" class="lazy" data-original="https://johnandbiola.co.uk/images/thumbs/0002049_groceries_290.jpeg" src="..."/>
# </a>
# </div>
# <ul class="subcategories">
# <li class="subcategory-item">
# <a href="/nido-milk-sugar" title="Canned"><span>Canned</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/indomie-3" title="Indomie"><span>Indomie</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/puree-plum" title="Plum, Puree"><span>Plum, Puree</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/cerelac" title="Baby, Beverages"><span>Baby, Beverages</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/variety" title="Variety"><span>Variety</span></a>
# </li>
# </ul>
# </div>
# </div><div class="box">
# <div class="title">
# <a href="/african" title="Grains, Flours"><span>Grains, Flours</span></a>
# </div>
# <div class="wrapper">
# <div class="picture">
# <a href="/african" title="Show products in category Grains, Flours">
# <img alt="Picture for category Grains, Flours" class="lazy" data-original="https://johnandbiola.co.uk/images/thumbs/0002002_grains-flours_290.jpeg" src="..."/>
# </a>
# </div>
# <ul class="subcategories">
# <li class="subcategory-item">
# <a href="/beans-lentils" title="Beans, Lentils"><span>Beans, Lentils</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/top-grains" title="Grains, Gari"><span>Grains, Gari</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/top-flours" title="Flours, Poundo"><span>Flours, Poundo</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/exotic-flours" title="Flours Variety"><span>Flours Variety</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/general" title="Baking, Coatings"><span>Baking, Coatings</span></a>
# </li>
# </ul>
# </div>
# </div><div class="box">
# <div class="title">
# <a href="/rice-n-oil" title="Rice, Spaghetti "><span>Rice, Spaghetti </span></a>
# </div>
# <div class="wrapper">
# <div class="picture">
# <a href="/rice-n-oil" title="Show products in category Rice, Spaghetti ">
# <img alt="Picture for category Rice, Spaghetti " class="lazy" data-original="https://johnandbiola.co.uk/images/thumbs/0002514_rice-spaghetti_290.jpeg" src="..."/>
# </a>
# </div>
# <ul class="subcategories">
# <li class="subcategory-item">
# <a href="/sella-basmati" title="Basmati, Sella"><span>Basmati, Sella</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/aaa-fragrance" title="Dragon, Fragrance"><span>Dragon, Fragrance</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/easy-cook" title="Easy Cook"><span>Easy Cook</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/golden-sella" title="Long Grain"><span>Long Grain</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/general-rice" title="Speciality"><span>Speciality</span></a>
# </li>
# </ul>
# </div>
# </div><div class="box">
# <div class="title">
# <a href="/oils" title="Oils"><span>Oils</span></a>
# </div>
# <div class="wrapper">
# <div class="picture">
# <a href="/oils" title="Show products in category Oils">
# <img alt="Picture for category Oils" class="lazy" data-original="https://johnandbiola.co.uk/images/thumbs/0002847_oils_290.jpeg" src="..."/>
# </a>
# </div>
# <ul class="subcategories">
# <li class="subcategory-item">
# <a href="/cooking-oil" title="Retail Cooking Oil"><span>Retail Cooking Oil</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/catering-oil" title="Catering Oil"><span>Catering Oil</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/palm-zomi-oil" title="Palm, Zomi Oil"><span>Palm, Zomi Oil</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/speciality-oil" title="Speciality Oil"><span>Speciality Oil</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/non-edible-oil" title="Non Edible Oil"><span>Non Edible Oil</span></a>
# </li>
# </ul>
# </div>
# </div></div><div class="row"><div class="box">
# <div class="title">
# <a href="/eatery" title="Eatery"><span>Eatery</span></a>
# </div>
# <div class="wrapper">
# <div class="picture">
# <a href="/eatery" title="Show products in category Eatery">
# <img alt="Picture for category Eatery" class="lazy" data-original="https://johnandbiola.co.uk/images/thumbs/0002055_eatery_290.jpeg" src="..."/>
# </a>
# </div>
# <ul class="subcategories">
# <li class="subcategory-item">
# <a href="/bread-2" title="Bread"><span>Bread</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/drinks-4" title="Drinks"><span>Drinks</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/plantain-chips" title="Plantain Chips"><span>Plantain Chips</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/snacks" title="Nuts, Chin-Chin"><span>Nuts, Chin-Chin</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/sweets" title="Sweets"><span>Sweets</span></a>
# </li>
# </ul>
# </div>
# </div><div class="box">
# <div class="title">
# <a href="/meditereanian" title="Mediterranean"><span>Mediterranean</span></a>
# </div>
# <div class="wrapper">
# <div class="picture">
# <a href="/meditereanian" title="Show products in category Mediterranean">
# <img alt="Picture for category Mediterranean" class="lazy" data-original="https://johnandbiola.co.uk/images/thumbs/0002898_mediterranean_290.jpeg" src="..."/>
# </a>
# </div>
# <ul class="subcategories">
# <li class="subcategory-item">
# <a href="/dates" title="Speciality"><span>Speciality</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/herbs-spices" title="Herbs, Spices"><span>Herbs, Spices</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/rice" title="Pasta, Rice"><span>Pasta, Rice</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/grains-cereal" title="Beans, Cereal, Grain"><span>Beans, Cereal, Grain</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/malt-beverage-drinks" title="Drinks, Malt, Snacks"><span>Drinks, Malt, Snacks</span></a>
# </li>
# </ul>
# </div>
# </div><div class="box">
# <div class="title">
# <a href="/world-food" title="World, Ethnic"><span>World, Ethnic</span></a>
# </div>
# <div class="wrapper">
# <div class="picture">
# <a href="/world-food" title="Show products in category World, Ethnic">
# <img alt="Picture for category World, Ethnic" class="lazy" data-original="https://johnandbiola.co.uk/images/thumbs/0003029_world-ethnic_290.jpeg" src="..."/>
# </a>
# </div>
# <ul class="subcategories">
# <li class="subcategory-item">
# <a href="/essentials" title="Accessories"><span>Accessories</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/hair-2" title="Hair, Accessories"><span>Hair, Accessories</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/soap-2" title="Soap, Toiletries"><span>Soap, Toiletries</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/herbal-2" title="Balm, Cream, Herbal"><span>Balm, Cream, Herbal</span></a>
# </li>
# </ul>
# </div>
# </div><div class="box">
# <div class="title">
# <a href="/party-goods" title="Speciality, Non-Food"><span>Speciality, Non-Food</span></a>
# </div>
# <div class="wrapper">
# <div class="picture">
# <a href="/party-goods" title="Show products in category Speciality, Non-Food">
# <img alt="Picture for category Speciality, Non-Food" class="lazy" data-original="https://johnandbiola.co.uk/images/thumbs/0002280_speciality-non-food_290.jpeg" src="..."/>
# </a>
# </div>
# <ul class="subcategories">
# <li class="subcategory-item">
# <a href="/foil-containers" title="Food Containers"><span>Food Containers</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/plate-cup-cutlery" title="Plates &amp; Cups"><span>Plates &amp; Cups</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/plastic-container" title="Cutlery"><span>Cutlery</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/foil-trays-2" title="Trays &amp; Bowls"><span>Trays &amp; Bowls</span></a>
# </li>
# </ul>
# </div>
# </div></div>
# </div>
# </div>
# </li>
# <li class="has-sublist with-dropdown-in-grid">
# <a class="with-subcategories" href="/offers-4"><span>Wholesale</span></a>
# <div class="dropdown categories fullWidth boxes-4">
# <div class="row-wrapper">
# <div class="row"><div class="box">
# <div class="title">
# <a href="/partners-product-required" title="Vegetables"><span>Vegetables</span></a>
# </div>
# <div class="wrapper">
# <div class="picture">
# <a href="/partners-product-required" title="Show products in category Vegetables">
# <img alt="Picture for category Vegetables" class="lazy" data-original="https://johnandbiola.co.uk/images/thumbs/0002858_vegetables_290.png" src="..."/>
# </a>
# </div>
# <ul class="subcategories">
# <li class="subcategory-item">
# <a href="/fresh-leaf" title="Fresh Leaves"><span>Fresh Leaves</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/frozen" title="Frozen"><span>Frozen</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/plantain-yams" title="Plantain, Yams"><span>Plantain, Yams</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/seeds" title="Dry Leaves, Seeds"><span>Dry Leaves, Seeds</span></a>
# </li>
# </ul>
# </div>
# </div><div class="box">
# <div class="title">
# <a href="/products-required" title="Brands"><span>Brands</span></a>
# </div>
# <div class="wrapper">
# <div class="picture">
# <a href="/products-required" title="Show products in category Brands">
# <img alt="Picture for category Brands" class="lazy" data-original="https://johnandbiola.co.uk/images/thumbs/0002856_brands_290.png" src="..."/>
# </a>
# </div>
# <ul class="subcategories">
# <li class="subcategory-item">
# <a href="/ktc-brand" title="KTC,Oil,Beans,Rice"><span>KTC,Oil,Beans,Rice</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/rice-wholesale" title="Rice, Spaghetti "><span>Rice, Spaghetti </span></a>
# </li>
# <li class="subcategory-item">
# <a href="/spices-2" title="Spices"><span>Spices</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/sauces" title="Sauces"><span>Sauces</span></a>
# </li>
# </ul>
# </div>
# </div><div class="box">
# <div class="title">
# <a href="/products-on-offer" title="Groceries"><span>Groceries</span></a>
# </div>
# <div class="wrapper">
# <div class="picture">
# <a href="/products-on-offer" title="Show products in category Groceries">
# <img alt="Picture for category Groceries" class="lazy" data-original="https://johnandbiola.co.uk/images/thumbs/0002758_groceries_290.png" src="..."/>
# </a>
# </div>
# <ul class="subcategories">
# <li class="subcategory-item">
# <a href="/indomie-offered" title="Indomie"><span>Indomie</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/grains-wholesale" title="Grains, Flours"><span>Grains, Flours</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/puree" title="Plum, Puree"><span>Plum, Puree</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/beverages-drinks" title="Beverages, Drinks"><span>Beverages, Drinks</span></a>
# </li>
# </ul>
# </div>
# </div><div class="box">
# <div class="title">
# <a href="/partners-offers" title="Speciality"><span>Speciality</span></a>
# </div>
# <div class="wrapper">
# <div class="picture">
# <a href="/partners-offers" title="Show products in category Speciality">
# <img alt="Picture for category Speciality" class="lazy" data-original="https://johnandbiola.co.uk/images/thumbs/0002857_speciality_290.png" src="..."/>
# </a>
# </div>
# <ul class="subcategories">
# <li class="subcategory-item">
# <a href="/stockfish-wholesale" title="Stockfish"><span>Stockfish</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/general-offers" title="Ethnic, Exotic"><span>Ethnic, Exotic</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/drinks-5" title="Mediterranean"><span>Mediterranean</span></a>
# </li>
# <li class="subcategory-item">
# <a href="/world-food-2" title="World Food"><span>World Food</span></a>
# </li>
# </ul>
# </div>
# </div></div>
# </div>
# </div>
# </li>
# <li class="">
# <a class="" href="/newproducts" title="New Products"><span> New Products</span></a>
# </li>
# <li class="">
# <a class="" href="/delivery" title="Delivery"><span> Delivery</span></a>
# </li>
# <li class="">
# <a class="" href="/contactus-john-and-biola" target="_blank" title="Contact Us"><span> Contact Us</span></a>
# </li>
# </ul>
# <div class="menu-title"><span>Menu</span></div>
# <ul class="mega-menu-responsive">
# <li class="has-sublist">
# <a class="with-subcategories" href="/supermarket-shop"><span>Shop</span></a>
# <div class="plus-button"></div>
# <div class="sublist-wrap">
# <ul class="sublist">
# <li class="back-button">
# <span>Back</span>
# </li>
# <li class="has-sublist">
# <a class="with-subcategories" href="/meat" title="Meat"><span>Meat</span></a>
# <div class="plus-button"></div>
# <div class="sublist-wrap">
# <ul class="sublist">
# <li class="back-button">
# <span>Back</span>
# </li>
# <li>
# <a class="lastLevelCategory" href="/cow-ox" title="Beef"><span>Beef</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/chicken-hen" title="Chicken, Hen"><span>Chicken, Hen</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/goat" title="Goat, Lamb, Mutton"><span>Goat, Lamb, Mutton</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/turkey-fowl" title="Turkey"><span>Turkey</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/game" title="Exotics"><span>Exotics</span></a>
# </li>
# </ul>
# </div>
# </li>
# <li class="has-sublist">
# <a class="with-subcategories" href="/fish" title="Seafood"><span>Seafood</span></a>
# <div class="plus-button"></div>
# <div class="sublist-wrap">
# <ul class="sublist">
# <li class="back-button">
# <span>Back</span>
# </li>
# <li>
# <a class="lastLevelCategory" href="/frozen-fish" title="Fresh Frozen Fish"><span>Fresh Frozen Fish</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/stockfish" title="Stockfish"><span>Stockfish</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/prawns-crayfish" title="Prawns, Crayfish"><span>Prawns, Crayfish</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/smoked-seafood" title="Smoked, Grilled"><span>Smoked, Grilled</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/delicacy" title="Delicacy"><span>Delicacy</span></a>
# </li>
# </ul>
# </div>
# </li>
# <li class="has-sublist">
# <a class="with-subcategories" href="/vegetable" title="Vegetables"><span>Vegetables</span></a>
# <div class="plus-button"></div>
# <div class="sublist-wrap">
# <ul class="sublist">
# <li class="back-button">
# <span>Back</span>
# </li>
# <li>
# <a class="lastLevelCategory" href="/everyday-vegetable" title="Everyday"><span>Everyday</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/plantain" title="Plantain, Yams"><span>Plantain, Yams</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/fresh-leaves" title="Leaves, Seeds"><span>Leaves, Seeds</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/exotic-veg" title="Exotic, Fruit, Herbal"><span>Exotic, Fruit, Herbal</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/frozen-vegetable" title="Frozen"><span>Frozen</span></a>
# </li>
# </ul>
# </div>
# </li>
# <li class="has-sublist">
# <a class="with-subcategories" href="/spices-cubes" title="Spices, Seasonings "><span>Spices, Seasonings </span></a>
# <div class="plus-button"></div>
# <div class="sublist-wrap">
# <ul class="sublist">
# <li class="back-button">
# <span>Back</span>
# </li>
# <li>
# <a class="lastLevelCategory" href="/jumbo-spices" title="Seasonings"><span>Seasonings</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/exotics" title="Ethnic"><span>Ethnic</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/rajah-spices" title="Rajah"><span>Rajah</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/cubes-sauces" title="Sauces, Paste"><span>Sauces, Paste</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/cubes" title="Chutneys, Pickles"><span>Chutneys, Pickles</span></a>
# </li>
# </ul>
# </div>
# </li>
# <li class="has-sublist">
# <a class="with-subcategories" href="/groceries" title="Groceries"><span>Groceries</span></a>
# <div class="plus-button"></div>
# <div class="sublist-wrap">
# <ul class="sublist">
# <li class="back-button">
# <span>Back</span>
# </li>
# <li>
# <a class="lastLevelCategory" href="/nido-milk-sugar" title="Canned"><span>Canned</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/indomie-3" title="Indomie"><span>Indomie</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/puree-plum" title="Plum, Puree"><span>Plum, Puree</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/cerelac" title="Baby, Beverages"><span>Baby, Beverages</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/variety" title="Variety"><span>Variety</span></a>
# </li>
# </ul>
# </div>
# </li>
# <li class="has-sublist">
# <a class="with-subcategories" href="/african" title="Grains, Flours"><span>Grains, Flours</span></a>
# <div class="plus-button"></div>
# <div class="sublist-wrap">
# <ul class="sublist">
# <li class="back-button">
# <span>Back</span>
# </li>
# <li>
# <a class="lastLevelCategory" href="/beans-lentils" title="Beans, Lentils"><span>Beans, Lentils</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/top-grains" title="Grains, Gari"><span>Grains, Gari</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/top-flours" title="Flours, Poundo"><span>Flours, Poundo</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/exotic-flours" title="Flours Variety"><span>Flours Variety</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/general" title="Baking, Coatings"><span>Baking, Coatings</span></a>
# </li>
# </ul>
# </div>
# </li>
# <li class="has-sublist">
# <a class="with-subcategories" href="/rice-n-oil" title="Rice, Spaghetti "><span>Rice, Spaghetti </span></a>
# <div class="plus-button"></div>
# <div class="sublist-wrap">
# <ul class="sublist">
# <li class="back-button">
# <span>Back</span>
# </li>
# <li>
# <a class="lastLevelCategory" href="/sella-basmati" title="Basmati, Sella"><span>Basmati, Sella</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/aaa-fragrance" title="Dragon, Fragrance"><span>Dragon, Fragrance</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/easy-cook" title="Easy Cook"><span>Easy Cook</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/golden-sella" title="Long Grain"><span>Long Grain</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/general-rice" title="Speciality"><span>Speciality</span></a>
# </li>
# </ul>
# </div>
# </li>
# <li class="has-sublist">
# <a class="with-subcategories" href="/oils" title="Oils"><span>Oils</span></a>
# <div class="plus-button"></div>
# <div class="sublist-wrap">
# <ul class="sublist">
# <li class="back-button">
# <span>Back</span>
# </li>
# <li>
# <a class="lastLevelCategory" href="/cooking-oil" title="Retail Cooking Oil"><span>Retail Cooking Oil</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/catering-oil" title="Catering Oil"><span>Catering Oil</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/palm-zomi-oil" title="Palm, Zomi Oil"><span>Palm, Zomi Oil</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/speciality-oil" title="Speciality Oil"><span>Speciality Oil</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/non-edible-oil" title="Non Edible Oil"><span>Non Edible Oil</span></a>
# </li>
# </ul>
# </div>
# </li>
# <li class="has-sublist">
# <a class="with-subcategories" href="/eatery" title="Eatery"><span>Eatery</span></a>
# <div class="plus-button"></div>
# <div class="sublist-wrap">
# <ul class="sublist">
# <li class="back-button">
# <span>Back</span>
# </li>
# <li>
# <a class="lastLevelCategory" href="/bread-2" title="Bread"><span>Bread</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/drinks-4" title="Drinks"><span>Drinks</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/plantain-chips" title="Plantain Chips"><span>Plantain Chips</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/snacks" title="Nuts, Chin-Chin"><span>Nuts, Chin-Chin</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/sweets" title="Sweets"><span>Sweets</span></a>
# </li>
# </ul>
# </div>
# </li>
# <li class="has-sublist">
# <a class="with-subcategories" href="/meditereanian" title="Mediterranean"><span>Mediterranean</span></a>
# <div class="plus-button"></div>
# <div class="sublist-wrap">
# <ul class="sublist">
# <li class="back-button">
# <span>Back</span>
# </li>
# <li>
# <a class="lastLevelCategory" href="/dates" title="Speciality"><span>Speciality</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/herbs-spices" title="Herbs, Spices"><span>Herbs, Spices</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/rice" title="Pasta, Rice"><span>Pasta, Rice</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/grains-cereal" title="Beans, Cereal, Grain"><span>Beans, Cereal, Grain</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/malt-beverage-drinks" title="Drinks, Malt, Snacks"><span>Drinks, Malt, Snacks</span></a>
# </li>
# </ul>
# </div>
# </li>
# <li class="has-sublist">
# <a class="with-subcategories" href="/world-food" title="World, Ethnic"><span>World, Ethnic</span></a>
# <div class="plus-button"></div>
# <div class="sublist-wrap">
# <ul class="sublist">
# <li class="back-button">
# <span>Back</span>
# </li>
# <li>
# <a class="lastLevelCategory" href="/essentials" title="Accessories"><span>Accessories</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/hair-2" title="Hair, Accessories"><span>Hair, Accessories</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/soap-2" title="Soap, Toiletries"><span>Soap, Toiletries</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/herbal-2" title="Balm, Cream, Herbal"><span>Balm, Cream, Herbal</span></a>
# </li>
# </ul>
# </div>
# </li>
# <li class="has-sublist">
# <a class="with-subcategories" href="/party-goods" title="Speciality, Non-Food"><span>Speciality, Non-Food</span></a>
# <div class="plus-button"></div>
# <div class="sublist-wrap">
# <ul class="sublist">
# <li class="back-button">
# <span>Back</span>
# </li>
# <li>
# <a class="lastLevelCategory" href="/foil-containers" title="Food Containers"><span>Food Containers</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/plate-cup-cutlery" title="Plates &amp; Cups"><span>Plates &amp; Cups</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/plastic-container" title="Cutlery"><span>Cutlery</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/foil-trays-2" title="Trays &amp; Bowls"><span>Trays &amp; Bowls</span></a>
# </li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# </li>
# <li class="has-sublist">
# <a class="with-subcategories" href="/offers-4"><span>Wholesale</span></a>
# <div class="plus-button"></div>
# <div class="sublist-wrap">
# <ul class="sublist">
# <li class="back-button">
# <span>Back</span>
# </li>
# <li class="has-sublist">
# <a class="with-subcategories" href="/partners-product-required" title="Vegetables"><span>Vegetables</span></a>
# <div class="plus-button"></div>
# <div class="sublist-wrap">
# <ul class="sublist">
# <li class="back-button">
# <span>Back</span>
# </li>
# <li>
# <a class="lastLevelCategory" href="/fresh-leaf" title="Fresh Leaves"><span>Fresh Leaves</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/frozen" title="Frozen"><span>Frozen</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/plantain-yams" title="Plantain, Yams"><span>Plantain, Yams</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/seeds" title="Dry Leaves, Seeds"><span>Dry Leaves, Seeds</span></a>
# </li>
# </ul>
# </div>
# </li>
# <li class="has-sublist">
# <a class="with-subcategories" href="/products-required" title="Brands"><span>Brands</span></a>
# <div class="plus-button"></div>
# <div class="sublist-wrap">
# <ul class="sublist">
# <li class="back-button">
# <span>Back</span>
# </li>
# <li>
# <a class="lastLevelCategory" href="/ktc-brand" title="KTC,Oil,Beans,Rice"><span>KTC,Oil,Beans,Rice</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/rice-wholesale" title="Rice, Spaghetti "><span>Rice, Spaghetti </span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/spices-2" title="Spices"><span>Spices</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/sauces" title="Sauces"><span>Sauces</span></a>
# </li>
# </ul>
# </div>
# </li>
# <li class="has-sublist">
# <a class="with-subcategories" href="/products-on-offer" title="Groceries"><span>Groceries</span></a>
# <div class="plus-button"></div>
# <div class="sublist-wrap">
# <ul class="sublist">
# <li class="back-button">
# <span>Back</span>
# </li>
# <li>
# <a class="lastLevelCategory" href="/indomie-offered" title="Indomie"><span>Indomie</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/grains-wholesale" title="Grains, Flours"><span>Grains, Flours</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/puree" title="Plum, Puree"><span>Plum, Puree</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/beverages-drinks" title="Beverages, Drinks"><span>Beverages, Drinks</span></a>
# </li>
# </ul>
# </div>
# </li>
# <li class="has-sublist">
# <a class="with-subcategories" href="/partners-offers" title="Speciality"><span>Speciality</span></a>
# <div class="plus-button"></div>
# <div class="sublist-wrap">
# <ul class="sublist">
# <li class="back-button">
# <span>Back</span>
# </li>
# <li>
# <a class="lastLevelCategory" href="/stockfish-wholesale" title="Stockfish"><span>Stockfish</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/general-offers" title="Ethnic, Exotic"><span>Ethnic, Exotic</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/drinks-5" title="Mediterranean"><span>Mediterranean</span></a>
# </li>
# <li>
# <a class="lastLevelCategory" href="/world-food-2" title="World Food"><span>World Food</span></a>
# </li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# </li>
# <li class="">
# <a class="" href="/newproducts" title="New Products"><span> New Products</span></a>
# </li>
# <li class="">
# <a class="" href="/delivery" title="Delivery"><span> Delivery</span></a>
# </li>
# <li class="">
# <a class="" href="/contactus-john-and-biola" target="_blank" title="Contact Us"><span> Contact Us</span></a>
# </li>
# </ul>
# </div>
# </div>
# <div class="search-box store-search-box">
# <form action="/search" id="small-search-box-form" method="get">
# <input aria-label="Search store" autocomplete="off" class="search-box-text" id="small-searchterms" name="q" placeholder="Search store" type="text"/>
# <input class="instantSearchResourceElement" data-defaultproductsortoption="0" data-highlightfirstfoundelement="true" data-instantsearchurl="/instantSearchFor" data-minkeywordlength="3" data-noresultsresourcetext=" No data found." data-numberofvisibleproducts="5" data-searchinproductdescriptions="true" data-searchpageurl="/search" type="hidden"/>
# <button class="button-1 search-box-button" type="submit">Search</button>
# </form>
# <div class="search-box-opener">Search</div>
# </div>
# <div class="header-flyout-cart">
# <div class="mobile-flyout-cart-toggle" title="Close">
# <span class="first"></span>
# <span class="second"></span>
# </div>
# <div class="flyout-cart-wrapper" data-flyoutcarturl="/PacificTheme/FlyoutShoppingCart">
# <div class="flyout-cart-link" id="topcartlink" title="Shopping cart">
# <a class="ico-cart no-items-in-cart" href="/cart">
# <span class="cart-qty-number-mobile">0</span>
# <span class="cart-qty-number-desktop"><strong>0</strong> item(s)</span>
# <span class="cart-qty sub-total"></span>
# </a>
# </div>
# <div class="flyout-cart" id="flyout-cart">
# <div class="mini-shopping-cart">
# <div class="count no-items-in-cart">
# You have no items in your shopping cart.            </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="overlayOffCanvas"></div>
# <div class="master-wrapper-content">
# <div class="ajaxCartInfo" data-addtowishlistbuttonselector=".add-to-wishlist-button" data-enableoncatalogpages="True" data-enableonproductpage="True" data-getajaxcartbuttonurl="/NopAjaxCart/GetAjaxCartButtonsAjax" data-minishoppingcartquatityformattingresource="({0})" data-miniwishlistquatityformattingresource="({0})" data-nopnotificationcartresource='The product has been added to your &lt;a href="/cart"&gt;shopping cart&lt;/a&gt;' data-nopnotificationwishlistresource='The product has been added to your &lt;a href="/wishlist"&gt;wishlist&lt;/a&gt;' data-productboxaddtocartbuttonselector=".product-box-add-to-cart-button" data-productboxproductitemelementselector=".product-item" data-productpageaddtocartbuttonselector=".add-to-cart-button" data-usenopnotification="False">
# </div>
# <input id="addProductVariantToCartUrl" name="addProductVariantToCartUrl" type="hidden" value="/AddProductFromProductDetailsPageToCartAjax"/>
# <input id="addProductToCartUrl" name="addProductToCartUrl" type="hidden" value="/AddProductToCartAjax"/>
# <input id="miniShoppingCartUrl" name="miniShoppingCartUrl" type="hidden" value="/MiniShoppingCart"/>
# <input id="flyoutShoppingCartUrl" name="flyoutShoppingCartUrl" type="hidden" value="/NopAjaxCartFlyoutShoppingCart"/>
# <input id="checkProductAttributesUrl" name="checkProductAttributesUrl" type="hidden" value="/CheckIfProductOrItsAssociatedProductsHasAttributes"/>
# <input id="getMiniProductDetailsViewUrl" name="getMiniProductDetailsViewUrl" type="hidden" value="/GetMiniProductDetailsView"/>
# <input id="flyoutShoppingCartPanelSelector" name="flyoutShoppingCartPanelSelector" type="hidden" value="#flyout-cart"/>
# <input id="shoppingCartMenuLinkSelector" name="shoppingCartMenuLinkSelector" type="hidden" value="span.cart-qty"/>
# <input id="wishlistMenuLinkSelector" name="wishlistMenuLinkSelector" type="hidden" value="span.wishlist-qty"/>
# <div data-productboxpicturecontainerselector=".picture, .item-picture" data-productboxselector=".product-item, .item-holder" data-productid="0" data-productpagebugpicturecontainerselector=".picture" data-productpagepicturesparentcontainerselector=".product-essential" data-retrieveproductribbonsurl="/RetrieveProductRibbons" id="product-ribbon-info">
# </div>
# <div class="quickViewData" data-accordionpanelsheightstyle="content" data-enablequickviewpopupoverlay="True" data-getquickviewbuttonroute="/getquickviewbutton" data-isquickviewpopupdraggable="True" data-productselector=".product-item" data-productselectorchild=".product-item" data-quickviewbuttontext="Quick View" data-quickviewbuttontitle="Quick View" data-retrievequickviewurl="/quickviewdata">
# </div>
# <div class="master-column-wrapper">
# <div class="center-2 category-page-two-columns">
# <div class="page category-page">
# <div class="breadcrumb">
# <ul itemscope="" itemtype="http://schema.org/BreadcrumbList">
# <li>
# <a href="/" title="Home">Home</a>
# <span class="delimiter">/</span>
# </li>
# <li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <a href="/supermarket-shop" itemprop="item" title="Shop">
# <span itemprop="name">Shop</span>
# </a>
# <span class="delimiter">/</span>
# </li>
# <li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <strong class="current-item" itemprop="name">Vegetables</strong>
# <span id="/vegetable" itemprop="item" itemscope="" itemtype="http://schema.org/Thing">
# </span>
# </li>
# </ul>
# </div>
# <div class="page-title">
# <h1>Vegetables</h1>
# </div>
# <div class="page-body">
# <div class="category-grid sub-category-grid">
# <div class="item-grid">
# <div class="item-box">
# <div class="sub-category-item">
# <div class="picture">
# <a href="/everyday-vegetable" title="Show products in category Everyday">
# <img alt="Picture for category Everyday" data-lazyloadsrc="https://johnandbiola.co.uk/images/thumbs/0002592_everyday_230.jpeg" src="..." title="Show products in category Everyday"/>
# </a>
# </div>
# <div class="title">
# <div class="title-content-wrapper">
# <a href="/everyday-vegetable" title="Show products in category Everyday">
#                                             Everyday
#                                         </a>
# </div>
# </div>
# </div>
# </div>
# <div class="item-box">
# <div class="sub-category-item">
# <div class="picture">
# <a href="/plantain" title="Show products in category Plantain, Yams">
# <img alt="Picture for category Plantain, Yams" data-lazyloadsrc="https://johnandbiola.co.uk/images/thumbs/default-image_230.png" src="..." title="Show products in category Plantain, Yams"/>
# </a>
# </div>
# <div class="title">
# <div class="title-content-wrapper">
# <a href="/plantain" title="Show products in category Plantain, Yams">
#                                             Plantain, Yams
#                                         </a>
# </div>
# </div>
# </div>
# </div>
# <div class="item-box">
# <div class="sub-category-item">
# <div class="picture">
# <a href="/fresh-leaves" title="Show products in category Leaves, Seeds">
# <img alt="Picture for category Leaves, Seeds" data-lazyloadsrc="https://johnandbiola.co.uk/images/thumbs/default-image_230.png" src="..." title="Show products in category Leaves, Seeds"/>
# </a>
# </div>
# <div class="title">
# <div class="title-content-wrapper">
# <a href="/fresh-leaves" title="Show products in category Leaves, Seeds">
#                                             Leaves, Seeds
#                                         </a>
# </div>
# </div>
# </div>
# </div>
# <div class="item-box">
# <div class="sub-category-item">
# <div class="picture">
# <a href="/exotic-veg" title="Show products in category Exotic, Fruit, Herbal">
# <img alt="Picture for category Exotic, Fruit, Herbal" data-lazyloadsrc="https://johnandbiola.co.uk/images/thumbs/default-image_230.png" src="..." title="Show products in category Exotic, Fruit, Herbal"/>
# </a>
# </div>
# <div class="title">
# <div class="title-content-wrapper">
# <a href="/exotic-veg" title="Show products in category Exotic, Fruit, Herbal">
#                                             Exotic, Fruit, Herbal
#                                         </a>
# </div>
# </div>
# </div>
# </div>
# <div class="item-box">
# <div class="sub-category-item">
# <div class="picture">
# <a href="/frozen-vegetable" title="Show products in category Frozen">
# <img alt="Picture for category Frozen" data-lazyloadsrc="https://johnandbiola.co.uk/images/thumbs/default-image_230.png" src="..." title="Show products in category Frozen"/>
# </a>
# </div>
# <div class="title">
# <div class="title-content-wrapper">
# <a href="/frozen-vegetable" title="Show products in category Frozen">
#                                             Frozen
#                                         </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="product-selectors">
# <div class="product-viewmode">
# <a class="viewmode-icon grid" data-viewmode="grid" title="Grid">Grid</a>
# <a class="viewmode-icon list" data-viewmode="list" title="List">List</a>
# </div>
# <div class="filters-button">
#         Filters
#     </div>
# <div class="product-page-size">
# <select aria-label="Select number of products per page" id="products-pagesize" name="products-pagesize"><option value="10">10</option>
# <option value="15">15</option>
# <option selected="selected" value="20">20</option>
# <option value="25">25</option>
# </select>
# <span>per page</span>
# </div>
# <div class="product-sorting">
# <select aria-label="Select product sort order" id="products-orderby" name="products-orderby"><option selected="selected" value="0">Position</option>
# <option value="5">Name: A to Z</option>
# <option value="6">Name: Z to A</option>
# <option value="10">Price: Low to High</option>
# <option value="11">Price: High to Low</option>
# <option value="15">Created on</option>
# </select>
# </div>
# </div>
# <div class="products-container">
# <div class="ajax-products-busy"></div>
# <div class="products-wrapper">
# <div class="product-grid">
# <div class="item-grid">
# <div class="item-box">
# <div class="product-item hover-variant-two" data-productid="2668">
# <div class="picture">
# <a href="/fresh-nigeria-vegetables-mega-mix-10-bunchesis-copy" title="Show details for Fresh Nigeria Vegetables (MEGA MIX - 10 Bunches)">
# <img alt="Picture of Fresh Nigeria Vegetables (MEGA MIX - 10 Bunches)" class="picture-img" src="https://johnandbiola.co.uk/images/thumbs/0003108_fresh-nigeria-vegetables-mega-mix-10-bunches_140.jpeg" title="Show details for Fresh Nigeria Vegetables (MEGA MIX - 10 Bunches)"/>
# </a>
# </div>
# <div class="details">
# <div class="details-top">
# <h2 class="product-title">
# <a href="/fresh-nigeria-vegetables-mega-mix-10-bunchesis-copy">Fresh Nigeria Vegetables (MEGA MIX - 10 Bunches)</a>
# </h2>
# </div>
# <div class="description">
# <font color="red">Order by Saturday for GUARANTEED next week delivery. UK arrival is Thursday.
#  </font>
# </div>
# <div class="prices">
# <span class="price only-price">£17.50</span>
# </div>
# <div class="add-info">
# <div class="buttons">
# <button class="button-2 product-box-add-to-cart-button" onclick="AjaxCart.addproducttocart_catalog('/addproducttocart/catalog/2668/1/1');return false;" type="button">Add to cart</button>
# <button class="button-2 add-to-wishlist-button" onclick="AjaxCart.addproducttocart_catalog('/addproducttocart/catalog/2668/2/1');return false;" title="Add to wishlist" type="button">Add to wishlist</button>
# <button class="button-2 add-to-compare-list-button" onclick="AjaxCart.addproducttocomparelist('/compareproducts/add/2668');return false;" title="Add to compare list" type="button">Add to compare list</button>
# </div>
# <a class="item-box-overlay" href="/fresh-nigeria-vegetables-mega-mix-10-bunchesis-copy" title="Show details for Fresh Nigeria Vegetables (MEGA MIX - 10 Bunches)">
# <span class="item-box-overlay-tint"></span>
# </a>
# </div>
# <div class="attribute-squares-wrapper"></div>
# </div>
# </div>
# </div>
# <div class="item-box">
# <div class="product-item hover-variant-two" data-productid="702">
# <div class="picture">
# <a href="/fresh-ugu" title="Show details for Fresh Ugu Leaf (Telfairia Occidentalis)">
# <img alt="Picture of Fresh Ugu Leaf (Telfairia Occidentalis)" class="picture-img" src="https://www.johnandbiola.co.uk/images/thumbs/0001526_fresh-ugu-leaf-telfairia-occidentalis_140.jpeg" title="Show details for Fresh Ugu Leaf (Telfairia Occidentalis)"/>
# </a>
# </div>
# <div class="details">
# <div class="details-top">
# ...
# <button class="button-2 add-to-compare-list-button" onclick="AjaxCart.addproducttocomparelist('/compareproducts/add/1496');return false;" title="Add to compare list" type="button">Add to compare list</button>
# </div>
# <a class="item-box-overlay" href="/fresh-soko" title="Show details for Fresh Soko Leaf (Celosia Argentea)">
# <span class="item-box-overlay-tint"></span>
# </a>
# </div>
# <div class="attribute-squares-wrapper"></div>
# </div>
# </div>
# </div>
# <div class="item-box">
# <div class="product-item hover-variant-two" data-productid="2395">
# <div class="picture">
# <a href="/green-chilli-long-pepper" title="Show details for Green Chilli Pepper">
# <img alt="Picture of Green Chilli Pepper" class="picture-img" src="https://johnandbiola.co.uk/images/thumbs/0002594_green-chilli-pepper_140.jpeg" title="Show details for Green Chilli Pepper"/>
# </a>
# </div>
# <div class="details">
# <div class="details-top">
# <h2 class="product-title">
# <a href="/green-chilli-long-pepper">Green Chilli Pepper</a>
# </h2>
# </div>
# <div class="description">
#             FRESH GREEN CHILLI LONG PEPPER
#         </div>
# <div class="prices">
# <span class="price only-price">£1.00</span>
# </div>
# <div class="add-info">
# <div class="buttons">
# <button class="button-2 add-to-wishlist-button" onclick="AjaxCart.addproducttocart_catalog('/addproducttocart/catalog/2395/2/1');return false;" title="Add to wishlist" type="button">Add to wishlist</button>
# <button class="button-2 add-to-compare-list-button" onclick="AjaxCart.addproducttocomparelist('/compareproducts/add/2395');return false;" title="Add to compare list" type="button">Add to compare list</button>
# </div>
# <a class="item-box-overlay" href="/green-chilli-long-pepper" title="Show details for Green Chilli Pepper">
# <span class="item-box-overlay-tint"></span>
# </a>
# </div>
# <div class="attribute-squares-wrapper"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="pager">
# <ul><li class="current-page"><span>1</span></li><li class="individual-page"><a data-page="2" href="https://johnandbiola.co.uk/vegetable?pagenumber=2">2</a></li><li class="individual-page"><a data-page="3" href="https://johnandbiola.co.uk/vegetable?pagenumber=3">3</a></li><li class="individual-page"><a data-page="4" href="https://johnandbiola.co.uk/vegetable?pagenumber=4">4</a></li><li class="individual-page"><a data-page="5" href="https://johnandbiola.co.uk/vegetable?pagenumber=5">5</a></li><li class="next-page"><a data-page="2" href="https://johnandbiola.co.uk/vegetable?pagenumber=2">Next</a></li><li class="last-page"><a data-page="6" href="https://johnandbiola.co.uk/vegetable?pagenumber=6">Last</a></li></ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="side-2">
# <div class="blocks-wrapper">
# <div class="block block-category-navigation">
# <div class="title">
# <strong>Categories</strong>
# </div>
# <div class="listbox" id="CategoryNavigationList">
# <ul class="list">
# <li class="active">
# <a href="/supermarket-shop">Shop
#             </a>
# <ul class="sublist">
# <li class="inactive">
# <a href="/meat">Meat
#             </a>
# </li>
# <li class="inactive">
# <a href="/fish">Seafood
#             </a>
# </li>
# <li class="active last">
# <a href="/vegetable">Vegetables
#             </a>
# <ul class="sublist">
# <li class="inactive">
# <a href="/everyday-vegetable">Everyday
#             </a>
# </li>
# <li class="inactive">
# <a href="/plantain">Plantain, Yams
#             </a>
# </li>
# <li class="inactive">
# <a href="/fresh-leaves">Leaves, Seeds
#             </a>
# </li>
# <li class="inactive">
# <a href="/exotic-veg">Exotic, Fruit, Herbal
#             </a>
# </li>
# <li class="inactive">
# <a href="/frozen-vegetable">Frozen
#             </a>
# </li>
# </ul>
# </li>
# <li class="inactive">
# <a href="/spices-cubes">Spices, Seasonings
#             </a>
# </li>
# <li class="inactive">
# <a href="/groceries">Groceries
#             </a>
# </li>
# <li class="inactive">
# <a href="/african">Grains, Flours
#             </a>
# </li>
# <li class="inactive">
# <a href="/rice-n-oil">Rice, Spaghetti
#             </a>
# </li>
# <li class="inactive">
# <a href="/oils">Oils
#             </a>
# </li>
# <li class="inactive">
# <a href="/eatery">Eatery
#             </a>
# </li>
# <li class="inactive">
# <a href="/meditereanian">Mediterranean
#             </a>
# </li>
# <li class="inactive">
# <a href="/world-food">World, Ethnic
#             </a>
# </li>
# <li class="inactive">
# <a href="/party-goods">Speciality, Non-Food
#             </a>
# </li>
# </ul>
# </li>
# <li class="inactive">
# <a href="/offers-4">Wholesale
#             </a>
# </li>
# <li class="inactive">
# <a href="/back-in-stock">Back In Stock
#             </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="block block-vendor-navigation">
# <div class="title">
# <strong>Vendors</strong>
# </div>
# <div class="listbox" id="VendorNavigationList">
# <ul class="list">
# <li><a href="/abc-foods">ABC Foods</a>
# </li>
# <li><a href="/ktc-edibles">KTC-EDIBLES</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="footer">
# <div class="footer-upper">
# <div class="footer-blocks-wrapper center">
# <div class="footer-block-center">
# <div class="newsletter">
# <div class="title">
# <strong>Newsletter</strong>
# </div>
# <div class="newsletter-subscribe" id="newsletter-subscribe-block">
# <div class="newsletter-email">
# <input aria-label="Sign up for our newsletter" class="newsletter-subscribe-text" id="newsletter-email" name="NewsletterEmail" placeholder="Enter your email here..." type="email" value=""/>
# <button class="button-1 newsletter-subscribe-button" id="newsletter-subscribe-button" type="button">
# <span>Subscribe</span>
# </button>
# </div>
# <div class="newsletter-validation">
# <span class="please-wait" id="subscribe-loading-progress" style="display: none;">Wait...</span>
# <span class="field-validation-valid" data-valmsg-for="NewsletterEmail" data-valmsg-replace="true"></span>
# </div>
# </div>
# <div class="newsletter-result" id="newsletter-result-block"></div>
# </div>
# <ul class="social-sharing">
# <li><a class="facebook" href="http://www.facebook.com/johnandbiola" rel="noopener noreferrer" target="_blank"></a></li>
# <li><a class="twitter" href="https://twitter.com/johnandbiola/" rel="noopener noreferrer" target="_blank"></a></li>
# <li><a class="youtube" href="https://www.youtube.com/channel/UCOD1-B8FxfuKztlXgacnvgg/" rel="noopener noreferrer" target="_blank"></a></li>
# </ul>
# </div>
# </div>
# <div class="footer-blocks-wrapper left">
# <div class="footer-block contact">
# <div class="title">
# <strong>Contact Info</strong>
# </div>
# <ul class="list footer-collapse">
# <li class="phone">
# <span>+447423798421</span>
# </li>
# <li class="work-time">
# <span>Mon-Sat 10.00 - 18.00</span>
# </li>
# <li class="e-mail">
# <span>admin@johnandbiola.co.uk</span>
# </li>
# <li class="address-city">
# <span>London SE28 0BQ, UK</span>
# </li>
# <li class="address-street">
# <span>71 - 73 Nathan Way</span>
# </li>
# </ul>
# </div>
# <div class="footer-block information">
# <div class="title">
# <strong>Information</strong>
# </div>
# <ul class="list footer-collapse">
# <li><a href="/aboutus">About Us</a></li>
# <li><a href="/conditionsofuse">Conditions of use</a></li>
# <li><a href="/privacyinfo">Privacy Notice</a></li>
# <li><a href="/delivery">Delivery</a></li>
# <li><a href="/fair-use-for-free-delivery">Free Delivery - Fair Use</a></li>
# </ul>
# </div>
# </div>
# <div class="footer-blocks-wrapper right">
# <div class="footer-block service">
# <div class="title">
# <strong>Customer Service</strong>
# </div>
# <ul class="list footer-collapse">
# <li><a href="/search">Search</a> </li>
# <li><a href="/recentlyviewedproducts">Recently viewed products</a></li>
# <li><a href="/compareproducts">Compare products list</a></li>
# <li><a href="/newproducts">New products</a></li>
# </ul>
# </div>
# <div class="footer-block account">
# <div class="title">
# <strong>My Account</strong>
# </div>
# <ul class="list footer-collapse">
# <li><a href="/customer/info">My account</a></li>
# <li><a href="/order/history">Orders</a></li>
# <li><a href="/customer/addresses">Addresses</a></li>
# <li><a href="/cart">Shopping cart</a></li>
# <li><a href="/wishlist">Wishlist</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="footer-lower">
# <div class="footer-lower-left">
# </div>
# <div class="footer-lower-right">
# <div class="footer-disclaimer">
#                 Copyright © 2021 John and Biola Foods. All rights reserved.
#             </div>
# </div>
# </div>
# </div>
# </div>
# <script src="/lib_npm/jquery/jquery.min.js"></script>
# <script src="/lib_npm/jquery-validation/jquery.validate.min.js"></script>
# <script src="/lib_npm/jquery-validation-unobtrusive/jquery.validate.unobtrusive.min.js"></script>
# <script src="/lib_npm/jquery-ui-dist/jquery-ui.min.js"></script>
# <script src="/lib_npm/jquery-migrate/jquery-migrate.min.js"></script>
# <script src="/js/public.common.js"></script>
# <script src="/js/public.ajaxcart.js"></script>
# <script src="/js/public.countryselect.js"></script>
# <script src="/lib/kendo/2020.1.406/js/kendo.core.min.js"></script>
# <script src="/lib/kendo/2020.1.406/js/kendo.userevents.min.js"></script>
# <script src="/lib/kendo/2020.1.406/js/kendo.draganddrop.min.js"></script>
# <script src="/lib/kendo/2020.1.406/js/kendo.popup.min.js"></script>
# <script src="/lib/kendo/2020.1.406/js/kendo.window.min.js"></script>
# <script src="/Plugins/SevenSpikes.Nop.Plugins.InstantSearch/Scripts/InstantSearch.min.js"></script>
# <script src="/lib/kendo/2020.1.406/js/kendo.data.min.js"></script>
# <script src="/lib/kendo/2020.1.406/js/kendo.list.min.js"></script>
# <script src="/lib/kendo/2020.1.406/js/kendo.autocomplete.min.js"></script>
# <script src="/lib/kendo/2020.1.406/js/kendo.fx.min.js"></script>
# <script src="/js/public.catalogproducts.js"></script>
# <script src="/Plugins/SevenSpikes.Core/Scripts/perfect-scrollbar.min.js"></script>
# <script src="/Plugins/SevenSpikes.Core/Scripts/sevenspikes.core.min.js"></script>
# <script src="/Plugins/SevenSpikes.Nop.Plugins.MegaMenu/Scripts/MegaMenu.min.js"></script>
# <script src="/Plugins/SevenSpikes.Core/Scripts/jquery.json-2.4.min.js"></script>
# <script src="/Plugins/SevenSpikes.Nop.Plugins.AjaxCart/Scripts/AjaxCart.min.js"></script>
# <script src="/Plugins/SevenSpikes.Nop.Plugins.ProductRibbons/Scripts/ProductRibbons.min.js"></script>
# <script src="/lib_npm/fine-uploader/jquery.fine-uploader/jquery.fine-uploader.min.js"></script>
# <script src="/Plugins/SevenSpikes.Nop.Plugins.QuickView/Scripts/QuickView.min.js"></script>
# <script src="/Plugins/SevenSpikes.Core/Scripts/cloudzoom.core.min.js"></script>
# <script src="/Plugins/SevenSpikes.Core/Scripts/slick-slider-1.6.0.min.js"></script>
# <script src="/Plugins/SevenSpikes.Core/Scripts/sevenspikes.theme.min.js"></script>
# <script src="/Themes/Pacific/Content/scripts/pacific.js"></script>
# <script>
#             $(document).ready(function () {
#                 var $viewModeEls = $('[data-viewmode]');
#                 $viewModeEls.on('click', function () {
#                     if (!$(this).hasClass('selected')) {
#                         $viewModeEls.toggleClass('selected');
#                         CatalogProducts.getProducts();
#                     }
#                     return false;
#                 });
#
#                 $(CatalogProducts).on('before', function (e) {
#                     var $viewModeEl = $('[data-viewmode].selected');
#                     if ($viewModeEl) {
#                         e.payload.urlBuilder
#                             .addParameter('viewmode', $viewModeEl.data('viewmode'));
#                     }
#                 });
#             });
#         </script>
# <script>
#             $(document).ready(function () {
#                 var $pageSizeEl = $('#products-pagesize');
#                 $pageSizeEl.on('change', function () {
#                     CatalogProducts.getProducts();
#                 });
#
#                 $(CatalogProducts).on('before', function (e) {
#                     e.payload.urlBuilder
#                         .addParameter('pagesize', $pageSizeEl.val());
#                 });
#             });
#         </script>
# <script>
#             $(document).ready(function () {
#                 var $orderByEl = $('#products-orderby');
#                 $orderByEl.on('change', function () {
#                     CatalogProducts.getProducts();
#                 });
#
#                 $(CatalogProducts).on('before', function (e) {
#                     e.payload.urlBuilder
#                         .addParameter('orderby', $orderByEl.val());
#                 });
#             });
#         </script>
# <script>
#     $(document).ready(function () {
#         CatalogProducts.init({
#             ajax: true,
#             browserPath: '/vegetable',
#             fetchUrl: '/category/products?categoryId=47'
#         });
#
#         addPagerHandlers();
#         $(CatalogProducts).on('loaded', function () {
#             addPagerHandlers();
#         });
#     });
#
#     function addPagerHandlers() {
#         $('[data-page]').on('click', function (e) {
#             e.preventDefault();
#             CatalogProducts.getProducts($(this).data('page'));
#             return false;
#         });
#     }
# </script>
# <script id="instantSearchItemTemplate" type="text/x-kendo-template">
#     <div class="instant-search-item" data-url="${ data.CustomProperties.Url }">
#         <a class="iOS-temp" href="${ data.CustomProperties.Url }">
#             <div class="img-block">
#                 <img src="${ data.DefaultPictureModel.ImageUrl }" alt="${ data.Name }" title="${ data.Name }" style="border: none">
#             </div>
#             <div class="detail">
#                 <div class="title">${ data.Name }</div>
#                 <div class="price"># var price = ""; if (data.ProductPrice.Price) { price = data.ProductPrice.Price } # #= price #</div>
#             </div>
#         </a>
#     </div>
# </script>
# <script>
#                 $("#small-search-box-form").on("submit", function(event) {
#                     if ($("#small-searchterms").val() == "") {
#                         alert('Please enter some search keyword');
#                         $("#small-searchterms").focus();
#                         event.preventDefault();
#                     }
#                 });
#             </script>
# <script>
#         var localized_data = {
#             AjaxCartFailure: "Failed to add the product. Please refresh the page and try one more time."
#         };
#         AjaxCart.init(false, '.header-links .cart-qty', '.header-links .wishlist-qty', '.flyout-cart-wrapper', localized_data);
#     </script>
# <script>
#         function newsletter_subscribe(subscribe) {
#             var subscribeProgress = $("#subscribe-loading-progress");
#             subscribeProgress.show();
#             var postData = {
#                 subscribe: subscribe,
#                 email: $("#newsletter-email").val()
#             };
#             $.ajax({
#                 cache: false,
#                 type: "POST",
#                 url: "/subscribenewsletter",
#                 data: postData,
#                 success: function(data) {
#                     subscribeProgress.hide();
#                     $("#newsletter-result-block").html(data.Result);
#                     if (data.Success) {
#                         $('#newsletter-subscribe-block').hide();
#                         $('#newsletter-result-block').show();
#                     } else {
#                         $('#newsletter-result-block').fadeIn("slow").delay(2000).fadeOut("slow");
#                     }
#                 },
#                 error: function(xhr, ajaxOptions, thrownError) {
#                     alert('Failed to subscribe.');
#                     subscribeProgress.hide();
#                 }
#             });
#         }
#
#         $(document).ready(function () {
#             $('#newsletter-subscribe-button').on('click', function () {
# newsletter_subscribe('true');            });
#             $("#newsletter-email").on("keydown", function (event) {
#                 if (event.keyCode == 13) {
#                     $("#newsletter-subscribe-button").trigger("click");
#                     return false;
#                 }
#             });
#         });
#     </script>
# <div class="scroll-back-button" id="goToTop"></div>
# </body>
# </html>

# %%
results = soup.find_all('div', {'class':'details'})

# %%
len(results)
# Out:
# 20

# %%
results[0]
# Out:
# <div class="details">
# <div class="details-top">
# <h2 class="product-title">
# <a href="/fresh-nigeria-vegetables-mega-mix-10-bunchesis-copy">Fresh Nigeria Vegetables (MEGA MIX - 10 Bunches)</a>
# </h2>
# </div>
# <div class="description">
# <font color="red">Order by Saturday for GUARANTEED next week delivery. UK arrival is Thursday.
#  </font>
# </div>
# <div class="prices">
# <span class="price only-price">£17.50</span>
# </div>
# <div class="add-info">
# <div class="buttons">
# <button class="button-2 product-box-add-to-cart-button" onclick="AjaxCart.addproducttocart_catalog('/addproducttocart/catalog/2668/1/1');return false;" type="button">Add to cart</button>
# <button class="button-2 add-to-wishlist-button" onclick="AjaxCart.addproducttocart_catalog('/addproducttocart/catalog/2668/2/1');return false;" title="Add to wishlist" type="button">Add to wishlist</button>
# <button class="button-2 add-to-compare-list-button" onclick="AjaxCart.addproducttocomparelist('/compareproducts/add/2668');return false;" title="Add to compare list" type="button">Add to compare list</button>
# </div>
# <a class="item-box-overlay" href="/fresh-nigeria-vegetables-mega-mix-10-bunchesis-copy" title="Show details for Fresh Nigeria Vegetables (MEGA MIX - 10 Bunches)">
# <span class="item-box-overlay-tint"></span>
# </a>
# </div>
# <div class="attribute-squares-wrapper"></div>
# </div>

# %%
results[0].find('h2', {'class': 'product-title'}).get_text().strip('\n')
# Out:
# 'Fresh Nigeria Vegetables (MEGA MIX - 10 Bunches)'

# %%
results[0].find('span', {'class': 'price only-price'}).get_text().strip('From')
# Out:
# '£17.50'

# %%
name = []
price = []

for result in results:
    
    #name
    try:
        name.append(result.find('h2', {'class': 'product-title'}).get_text().strip('\n'))
    except:
        name.append('n/a')
        
     #price
    try:
        price.append(result.find('span', {'class': 'price only-price'}).get_text().strip('From'))
    except:
        price.append('n/a')

# %%
price_overview = pd.DataFrame({'Name': name, 'Price': price })

# %%
price_overview
# Out:
#                                                  Name   Price
# 0    Fresh Nigeria Vegetables (MEGA MIX - 10 Bunches)  £17.50
# 1             Fresh Ugu Leaf (Telfairia Occidentalis)   £1.70
# 2                  Hot Pepper - Scotch Bonnet (Mixed)   £1.00
# 3                                       Ripe Plantain   £0.50
# 4   Frozen Whole Fresh Ugu Leaf (Telfairia Occiden...   £1.60
# 5             Fresh Bitter Leaf (Vernonia Amygdalina)   £1.70
# 6                  Hot Pepper - Scotch Bonnet (Green)   £1.00
# 7                                      Green Plantain   £0.50
# 8   Frozen Whole Fresh Bitter Leaf (Vernonia Amygd...   £1.60
# 9                                 Pona  Yam (NEW YAM)   £5.50
# 10                                        Okra - Okro   £1.00
# 11                             Fresh Molokhia (Ewedu)   £1.70
# 12                Frozen Whole Fresh Molokhia (Ewedu)   £1.60
# 13                        White (Ghana) Yam - NEW YAM   £5.50
# 14                         Fresh Green (Calaloo/Tete)   £1.70
# 15                                  Red Chilli Pepper   £1.00
# 16            Frozen Whole Fresh Green (Calaloo/Tete)   £1.60
# 17                        Water Yam (Dioscorea alata)   £4.50
# 18                 Fresh Soko Leaf (Celosia Argentea)   £1.70
# 19                                Green Chilli Pepper   £1.00

# %%
name = []
price = []

for i in range(1,7):
    
    #website in a variable
    website = 'https://johnandbiola.co.uk/vegetable?pagenumber=' + str(i) + '&viewmode=&pagesize=20&orderby=0'
    
    #request
    response = requests.get(website)
    
    # soup object
    soup = BeautifulSoup(response.content,'html.parser')
        
    #results
    results = soup.find_all('div', {'class':'details'})
    
    for result in results:
    
        #name
        try:
            name.append(result.find('h2', {'class': 'product-title'}).get_text().strip('\n'))
        except:
            name.append('n/a')

         #price
        try:
            price.append(result.find('span', {'class': 'price only-price'}).get_text().strip('From'))
        except:
            price.append('n/a')

# %%
price_overview = pd.DataFrame({'Name': name, 'Price': price })

# %%
price_overview
# Out:
#                                                   Name   Price
# 0     Fresh Nigeria Vegetables (MEGA MIX - 10 Bunches)  £17.50
# 1              Fresh Ugu Leaf (Telfairia Occidentalis)   £1.70
# 2                   Hot Pepper - Scotch Bonnet (Mixed)   £1.00
# 3                                        Ripe Plantain   £0.50
# 4    Frozen Whole Fresh Ugu Leaf (Telfairia Occiden...   £1.60
# ..                                                 ...     ...
# 113                              Ground Uziza Seed 30g   £1.70
# 114      Ground Utazi Leaf 20g (Gongronema Latifolium)   £1.70
# 115                              Ground Ehuru Seed 30g   £1.70
# 116                                Ground Uda Seed 30g   £1.70
# 117                               Ground Ukpo Seed 40g   £1.70
#
# [118 rows x 2 columns]

# %%
price_overview.to_excel('results_johnbiolavegetable_page.xlsx', index=False)
